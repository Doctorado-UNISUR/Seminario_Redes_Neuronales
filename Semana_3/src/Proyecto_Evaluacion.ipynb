# %% [markdown]
# <div align="center">
#
# # **Práctica de Redes Neuronales Artificiales**
#
# ---
#
# <img src="https://scontent-qro1-1.xx.fbcdn.net/v/t39.30808-6/324508895_1267558777141158_5075776834275102909_n.jpg?_nc_cat=100&ccb=1-7&_nc_sid=6ee11a&_nc_eui2=AeH_-KqfvlPVFh1ekkE0WOPpQZrk6zN4aPpBmuTrM3ho-jZQ7hoXQMNNyqbzbHD5o-s&_nc_ohc=5j-R8F19yicQ7kNvwE7zwBr&_nc_oc=AdlqcZ-Tf5CC89XsLiiCfESUReSIs0QmPASeQXtY7IsCTU64uuCSV5WUB4OUgxDenPv8VwbCpQ_mHnUN1PqNabOj&_nc_zt=23&_nc_ht=scontent-qro1-1.xx&_nc_gid=xBWqh7iaxddLABjy4DFn7g&oh=00_AfMpCsNxBhrWyVuPKVzKTpu2W_pOnvbYc3XkYDXzOHwG2Q&oe=684AD2EA" alt="Logo de la Institución" width="400">
#
# ---
# <h3>Universidad del Sur</h3>
# <h3>Doctorado en Sistemas Computacionales</h3>
# <h3>DSIC409 - Seminario de Redes Neuronales</h3>
# <h3>Docente: Dr. Rodolfo Esteban Ibarra</h3>
#
# <h3>Estudiante: Juan Carlos González Ibarra</h3>
# <h3>Correo Institucional: jcgi.laboral@gmail.com</h3>
#
# ---
#
# <h3>Fecha: 27 de junio, 2025</h3>
#
# </div>
#
# ---

# %% [markdown]
# ## Índice
#
# #### 1. **Introducción**
#
# #### 2. **Antecedentes**
# - 2.1 **Análisis Exploratorio de Datos**
# - 2.2 **Metodología en el Análisis de Datos**
# - 2.3 **Modelado de datos**
#     - 2.3.1 **Tipos de Modelos**
# - 2.4 **Métodos de Modelado**
#     - 2.4.1 **Modelo No Supervisado**
#     - 2.4.2 **Modelo Supervisado**
#     - 2.4.3 **Técnicas**
#
# #### 3. **Descripción del Tema**
# - 3.1 **Planteamiento del problema**
# - 3.2 **Tema de investigación**
# - 3.3 **Pregunta de investigación**
# - 3.4 **Objetivo General**
# - 3.5 **Objetivos particulares**
# - 3.6 **Justificación**
#
# #### 4. **Metodología de Desarrollo**
# - 4.1 **Definición de la(s) Variable(s) Objetivo(s)**
#
# #### 5. **Data Clean**
# - 5.1 **Descripción de los datos**
# - 5.2 **Carga de Datos**
# - 5.3 **Preprocesar los datos**
#
# #### 6. **Análisis exploratorio de Datos (AED)**
# - 6.1 **Análisis sobre las variables categóricas `marital_status` (estado civil) y `gender` (género)**
#     - 6.1.1 **Información relevante**
# - 6.2 **Análisis de `application_mode` y `application_order` vs `target`**
#     - 6.2.1 **Interpretación de gráficas**
# -- 6.3 **Análisis de impacto del nivel educativo de los padres y del estudiante en la deserción escolar**
#     - 6.3.1 **Información relevante**
# - 6.4 **Análisis cruzado: deudas vs tasa de deserción**
#     - 6.4.1 **Información relevante**
# - 6.5 **Análisis agrupados por target para calificaciones y edad de ingreso**
#     - 6.5.1 **Información relevante**
# - 6.6 **Análisis de comparación de carga académica, calificaciones y aprobaciones por semestre**
#     - 6.6.1 **Información relevante**
# - 6.7 **Análisis de balanceo de clases en la variable objetivo 'target'**
#     - 6.7.1 **Información relevante**
#
# #### 7. **Resultados de AED**
#
# #### 8. **Modelado de Datos**
# - 8.1 **Carga de datos**
# - 8.2 **Selección de datos de entrenamiento, validación y prueba**
# - 8.3 **Visualización de los datos de entrenamiento, validación y prueba**
# - 8.4 **Construcción del modelo**
#     - 8.4.1 **Algoritmo Backpropagation**
#     - 8.4.2 **Arquitectura de la RNA**
#     - 8.4.3 **Entrenamiento del Modelo**
#         - 8.4.3.1 **Entrenamiento con backprop y SGD**
#     - 8.4.4 **Validación del modelo**
#
# #### 9. **Resultados de validación y prueba del modelo de red neuronal**
#
# #### 10. **Conclusión**
#
# #### 11. **Bibliografía**
#
# ---

# %% [markdown]
# # 1. **Introducción**
#
# Las Redes Neuronales Artificiales (RNAs) han demostrado ser herramientas efectivas en diversas áreas del análisis de datos, gracias a su capacidad para aproximar funciones complejas y clasificar elementos a partir de múltiples variables. Esto permite abordar problemas de clasificación y predicción en contextos donde los datos presentan relaciones no lineales o patrones difíciles de identificar.
#
# Las RNAs han sido aplicadas con éxito en tareas como la predicción de tendencias, la segmentación de usuarios, la recomendación de productos y la clasificación de patrones de comportamiento. Son especialmente útiles en proyectos donde se requiere analizar grandes volúmenes de datos.
#
# Entre los modelos de RNA más representativos se encuentran las redes de propagación hacia adelante como el perceptrón multicapa (Multilayer Perceptron, MLP), las redes de funciones de base radial (Radial Basis Function, RBF) y las máquinas de vectores de soporte (Support Vector Machine, SVM). La principal diferencia entre ellos radica en su arquitectura: mientras que las RBF y SVM suelen contar con una sola capa oculta que transforma el espacio de entrada, el MLP puede tener múltiples capas ocultas, lo que le permite modelar relaciones más complejas.
#
# El proceso de entrenamiento también varía entre estos modelos. Tanto el MLP como las RBF suelen entrenarse minimizando el error entre las predicciones y los datos reales, mientras que las SVM buscan maximizar la separación entre las diferentes clases. A pesar de estas diferencias, todos comparten características como ser clasificadores universales, transformar el espacio de entrada y operar como clasificadores lineales bajo un enfoque supervisado, trabajando principalmente con datos numéricos reales.
#
# Este enfoque supervisado es una de las bases del aprendizaje automático o machine learning, una rama de la inteligencia artificial que permite a las máquinas aprender a realizar tareas sin ser explícitamente programadas para cada una, simulando la forma en que aprenden los humanos.
#
# Para entrenar estas redes, uno de los algoritmos más utilizados es backpropagation (o propagación hacia atrás del error), el cual permite ajustar los parámetros internos de la red para minimizar los errores de predicción. Inspirado en el funcionamiento del cerebro humano, este método considera la red como un conjunto de neuronas artificiales organizadas en capas que procesan los datos y propagan señales hacia adelante y hacia atrás.
#
# El algoritmo backpropagation se basa en la regla de la cadena para calcular el gradiente de error y ajustar los pesos y sesgos de cada nodo. El proceso consta de varias fases: primero se definen los puntos de entrada y salida; luego se determina el error total entre la salida esperada y la obtenida; finalmente, se propaga el error hacia atrás ajustando los parámetros hasta minimizar dicha diferencia. Este procedimiento se repite iterativamente hasta que el error sea suficientemente bajo.
#
# Gracias a este proceso, los nodos intermedios de la red neuronal aprenden a reconocer patrones relevantes, lo que permite a la red generalizar su aprendizaje y realizar predicciones incluso frente a datos incompletos o ruidosos.
#
# El método de backpropagation ha tenido éxito en aplicaciones como el reconocimiento óptico de caracteres, la conversión de texto a voz y el análisis de imágenes médicas.
#
# Para realizar este tipo de aplicaciones se requiere el manejo y análisis de enormes volúmenes de datos que no pueden ser procesados de manera efectiva con técnicas tradicionales. Los datos pueden provenir de varias fuentes, como repositorios, datasets, transacciones comerciales, sensores de IoT, redes sociales, datos de salud, etc. Las técnicas de análisis de datos permiten descubrir patrones ocultos, correlaciones y otras ideas útiles que pueden informar la toma de decisiones empresariales y estratégicas. Por lo que, para realizar este análisis masivo de datos, se debe identificar patrones que ayuden a la toma de decisiones y llevar a cabo el **Análisis Exploratorio de Datos (AED)**.
#
# ---

# %% [markdown]
# # 2. **Antecedentes**
#
# ## 2.1 **Análisis Exploratorio de Datos**
#
# Se utiliza para analizar e investigar conjuntos de datos y resumir sus características principales, a menudo empleando métodos de visualización de datos que ayuda a entender la estructura de estos. Es un paso crucial antes de realizar modelos más complejos ya que ayuda a gestionar las fuentes de datos, descubrir patrones, detectar anomalías, probar una hipótesis, identificar relaciones y tendencias, etc.
#
# <p align="center">
#   <img src="https://datos.gob.es/sites/default/files/u322/grafico-guia_0.jpg" width="600" height="400">
# </p>
#
# El **AED** es un paso esencial en cualquier flujo de trabajo de **análisis de datos**, implica el uso de algoritmos de muestreo y agregación para reducir la escala de los datos a un tamaño manejable, y luego explorar estos datos resumidos para obtener insights.
#
#
# El **AED** forma parte de cualquier **metodología para el análisis de datos**. Es una fase inicial en la que los analistas examinan los datos para comprender sus características principales antes de aplicar modelos más complejos. Aquí es cómo el AED se vincula con una metodología general para el **análisis de datos**.
#
# Source: https://www.ibm.com/mx-es/topics/exploratory-data-analysis
#
# ---

# %% [markdown]
# ## 2.2 **Metodología en el Análisis de Datos**
#
# Para establecer una metodología en el análisis de datos, debemos definir que el análisis de datos es el proceso de convertir datos sin procesar en información práctica e incluye una serie de herramientas, tecnologías y procesos para encontrar tendencias y resolver problemas mediante datos.
#
# <p align="center">
# <img src="https://actions.es/wp-content/uploads/2020/08/datos1-1.jpg" width="600" height="400">
# </p>
#
# Source: https://aws.amazon.com/es/what-is/data-analytics/

# %% [markdown]
# Existen metodologías para el análisis de datos, en esta guía básica realizada por Non-Profit Evaluation & Resource Center, Inc. (NPERCI) presenta los pasos generales para procesar y analizar datos.
#
# Definición del problema: Antes de comenzar cualquier análisis, es crucial definir claramente el problema que se está tratando de resolver. Esto implica entender el contexto del problema y los objetivos del análisis.
#
# Recolección de datos: Una vez definido el problema, el siguiente paso es recoger los datos necesarios para el análisis. Esto puede implicar la extracción de datos de bases de datos, archivos, APIs, servicios web, etc.
#
# Limpieza de datos: Los datos rara vez están limpios y listos para analizar. Es probable que necesites limpiarlos, lo que puede implicar tratar con datos faltantes, eliminar duplicados, corregir errores, etc.
#
# Análisis Exploratorio de Datos (AED): Una vez que los datos están limpios, el siguiente paso es explorarlos para entender sus características principales. Esto puede implicar visualizar los datos, calcular estadísticas descriptivas, identificar outliers, examinar correlaciones entre variables, etc. El objetivo del AED es obtener una comprensión clara de los datos y formular hipótesis sobre posibles relaciones y patrones en los datos.
#
# **Modelado de datos**: Después del AED, puedes comenzar a construir modelos de datos, como modelos de regresión, modelos de clasificación, clusters, etc., dependiendo del problema que estés tratando de resolver.
#
# Evaluación del modelo: Una vez que tienes un modelo, necesitas evaluar su rendimiento. Esto puede implicar técnicas como la validación cruzada, el uso de conjuntos de prueba y validación, y el cálculo de métricas de rendimiento.
#
# Interpretación y comunicación de resultados: Finalmente, interpretas los resultados de tu modelo y los comunicas a otras partes interesadas. Esto puede implicar la creación de visualizaciones, informes o presentaciones.
#
# <p align="center">
# <img src="https://www.questionpro.com/userimages/site_media/como-hacer-un-analisis-de-datos.jpeg" width="600" height="400">
# </p>
#
# Source: https://nperci.org
#
# ---

# %% [markdown]
# ## 2.3 **Modelado de datos**
#
# La etapa de modelado utiliza la primera versión del conjunto de datos preparado y se enfoca en desarrollar modelos predictivos o descriptivos, a partir del uso de modelos estadísticos o matemáticos según el enfoque analítico previamente definido. La definición del modelo depende del objetivo con el que se vaya a realizar el AED, mediante la definición del objetivo podemos establecer el modelo (descriptivo y/o predictivo).
#
# ### 2.3.1 **Tipos de Modelos**
#
# **Modelo Descriptivo**
#
# El modelo descriptivo, se utiliza para describir o resumir un conjunto de datos o fenómenos observados. Su objetivo principal es comprender y comunicar las características, patrones o relaciones presentes en los datos y proporcionar información descriptiva sobre los datos. Se pueden platear preguntas como "¿qué está sucediendo?", "¿cuáles son las características principales de los datos?" o "¿cómo se relacionan las variables entre sí?".
#
# **Modelo Diagnóstico**
#
# El modelo diagnóstico se utiliza para analizar datos históricos y comprender las causas o factores que han llevado a un resultado específico. Su objetivo principal es identificar relaciones y patrones que expliquen por qué ocurrió un evento o fenómeno en particular. Este modelo responde preguntas como "¿por qué sucedió esto?", "¿cuáles fueron los factores que influyeron en este resultado?" o "¿qué variables están asociadas con este comportamiento?". El análisis diagnóstico es fundamental para entender el contexto y las razones detrás de los resultados observados, permitiendo tomar decisiones informadas para evitar errores o replicar éxitos en el futuro.
#
# **Modelo Predictivo**
#
# El modelo predictivo, se utiliza en un conjunto de capacitación (datos históricos en los que se conoce el resultado de interés) para construir el modelo, ya que su objetivo es predecir la probabilidad de éxito de un variable en función de variables específicas y hacer predicciones sobre eventos futuros. Este modelo busca responder preguntas como "¿qué sucederá en el futuro?", "¿cuál será el resultado de cierto evento?" o "¿cuál es la probabilidad de que ocurra un determinado resultado?".
#
# **Modelo Prescriptivo**
#
# El modelo prescriptivo va un paso más allá del diagnóstico y la predicción, ya que no solo busca anticipar lo que podría suceder, sino también recomendar acciones concretas para alcanzar un resultado deseado. Utiliza datos históricos, modelos predictivos y reglas de negocio para sugerir la mejor estrategia o decisión posible ante diferentes escenarios. Este modelo responde preguntas como "¿qué debo hacer para lograr un objetivo específico?", "¿cuál es la mejor acción a tomar dadas las circunstancias actuales?" o "¿cómo puedo optimizar los resultados futuros?". El análisis prescriptivo es clave para la toma de decisiones estratégicas, ya que ayuda a seleccionar el curso de acción más efectivo basado en datos y simulaciones.
#
# Independientemente del modelo que se va utilizar, se debe hacer uso de herramientas o técnicas que ayuden a entender el tipo de modelo y el objetivo del análisis; en el modelo descriptivos se pueden utilizar técnicas como medidas de tendencia central (como la media o la mediana), medidas de dispersión (como la desviación estándar o el rango Inter cuartil) y en el modelo predictivo, se van a utilizar **_Algoritmos_ (regresión, clasificación o series de tiempo)**  que revisan los datos y que son capaces de predecir comportamientos futuros.
#
# El proceso de modelado normalmente es muy iterativo, ya que las organizaciones están adquiriendo insights intermedios, lo que deriva en ajustes en la preparación de datos y en la especificación del modelo. Para una técnica determinada, se pueden probar múltiples algoritmos con sus respectivos parámetros para encontrar el mejor modelo para las variables disponibles. Cada método tiene ciertos puntos fuertes y es más adecuado para determinados tipos de problemas.
#
# Para ambos tipos de modelos se va a necesitar gráficos y visualizaciones de datos, AED, técnicas de agrupamiento o clustering, análisis de componentes principales (PCA) y análisis de correlación, que van a buscar utilizar estos datos para hacer proyecciones, descripciones y/o toma de decisiones basadas en las predicciones.
#
# <p align="center">
# <img src="https://www.martinsgattoni.com/wp-content/uploads/2022/03/image.png" width="600" height="400">
# </p>
#
#
# Source:  https://www.martinsgattoni.com/para-que-sirven-los-datos-breve-introduccion-a-los-niveles-de-analisis-y-sus-posibles-usos-en-marketing/
#
# ---

# %% [markdown]
# ## 2.4 **Métodos de Modelado**
#
# Los diferentes _Tipos de Modelo (descriptiv, diagnóstico, predictivo o rescriptivo)_ a implementar en áreas de la Inteligencia Artificial y el Machine Learning, permiten derivar nueva información procedente de los datos y desarrollar **Modelos predictivos**.
#
# Para iniciar a Modelar datos en el Modelo Predictivo, existen algunos métodos de modelado que se dividen en estas categorías:
#
# - No Supervisado.
#   - Asociación.
#   - Segmentación.
#
#
# - Supervisado.
#   - Clasificación.
#   - Regresión.
#
# <p align="center">
# <img src="https://blogdatlas.files.wordpress.com/2020/06/datlas_ml_supervised_notsupervised.png" width="600" height="400">
# </p>
#
# ## 2.4.1 **Modelo No Supervisado**
#
# El **_Modelo No Supervisado_**, es un tipo de modelo de aprendizaje automático en el que no se proporciona una variable objetivo previamente. En cambio, el modelo busca patrones y estructuras inherentes en los datos sin etiquetas. El objetivo principal de un modelo no supervisado es encontrar agrupaciones, similitudes o relaciones ocultas en los datos. Este tipo de modelo exploran los datos sin ninguna guía específica y pueden revelar información valiosa sobre las características y estructuras subyacentes de los datos. Los modelos no supervisados se utilizan en diversos casos, como la segmentación de clientes, la detección de anomalías, la reducción de dimensionalidad y la recomendación de productos. Existen tipos de modelos No Supervisado como el **_Modelos de asociación y Modelos de segmentación_**.
#
# **Modelos de asociación**
#
# Los modelos de asociación encuentran patrones en los datos en los que una o más entidades (como eventos, compras o atributos) se asocian con una o más entidades. Los modelos construyen conjuntos de reglas que definen estas relaciones. Aquí los campos de los datos pueden funcionar como entradas y destinos. Podría encontrar estas asociaciones manualmente, pero los algoritmos de reglas de asociaciones lo hacen mucho más rápido, y pueden explorar patrones más complejos. Los modelos Apriori y Carma son ejemplos del uso de estos algoritmos. Otro tipo de modelo de asociación es el modelo de detección de secuencias, que encuentra patrones secuenciales en datos estructurados temporalmente.
#
# Los modelos de asociación son los más útiles si se desean predecir varios resultados; por ejemplo, los clientes que adquirieron el producto X también adquirieron Y y Z. Los modelos de asociación relacionan una conclusión específica (como la decisión de adquirir un producto) con un conjunto de condiciones. La ventaja de los algoritmos de reglas de asociación sobre los algoritmos más estándar de árboles de decisión (C5.0 y Árbol C&R) es que las asociaciones pueden existir entre cualquiera de los atributos. Un algoritmo de árbol de decisión generará reglas con una única conclusión, mientras que los algoritmos de asociación tratan de buscar muchas reglas, cada una de las cuales puede tener una conclusión diferente.
#
# **Modelos de segmentación**
#
# Los modelos de segmentación dividen los datos en segmentos o clústeres de registros que tienen patrones similares de campos de entrada. Como sólo se interesan por los campos de entrada, los modelos de segmentación no contemplan el concepto de campos de salida o destino.
#
# Los modelos de segmentación (también conocidos como "modelos de agrupación en clústeres") son útiles en aquellos casos en los que se desconoce el resultado específico (por ejemplo, a la hora de detectar nuevos patrones de fraude o de identificar grupos de interés en la base de clientes). Los modelos de agrupación en clústeres se centran en la identificación de grupos de registros similares y en el etiquetado de registros según el grupo al que pertenecen. Esto se lleva a cabo sin la ventaja que ofrece el conocimiento previo sobre los grupos y sus características, y diferencia a los modelos de clústeres de otras técnicas de modelado en que no hay campos de salida u objetivo predefinidos para el modelo que se va a predecir. No hay respuestas correctas o incorrectas para estos modelos. Su valor viene determinado por su capacidad de capturar agrupaciones interesantes en los datos y proporcionar descripciones útiles de dichas agrupaciones. Los modelos de clúster se usan a menudo para crear clústeres o segmentos que se usan posteriormente como entradas en análisis posteriores, (por ejemplo, mediante la segmentación de clientes potenciales en subgrupos homogéneos).
#
# ## 2.4.2 Modelo Supervisado
#
# Los Modelos supervisados utilizan los valores de uno o varios campos de entrada para predecir el valor de uno o varios resultados o campos de destino, algunos ejemplos de estas técnicas son:
#
# - Vecino más próximo K.
# - Algoritmos de regresión.
#   - Lineal.
#   - Logística.
#   - Lineal generalizada.
#   - Random forest.
# - **_Redes neuronales._**.
# - Máquinas de vectores de soporte.
# - Redes bayesianas.
#
# <p align="center">
# <img src="https://blogdatlas.files.wordpress.com/2020/06/datlas_regression-vs-classification-in-machine-learning.png" width="600" height="400">
# </p>
#
# Los modelos supervisados ayudan a las organizaciones a predecir un resultado conocido, por ejemplo, si un cliente comprará o se irá o si una transacción se ajusta a un patrón conocido de fraude. Las técnicas de modelado incluyen aprendizaje automático de las máquinas, inducción de reglas, identificación de subgrupos, métodos estadísticos y generación de varios modelos.
#
# Ejemplos de casos de uso:
#
# - Categorización de siniestros. Podría categorizar las zonas más siniestradas de una ciudad entrenando un modelo con la historia de datos. De esta manera se podría generar mejores rutas de patrullaje por los policías.
#
# - Predecir el éxito. Para hoteles u hospedajes de AIRBNB podría predecir si van a tener éxito o no considerando las variables que comunican en sus anuncios.
#
# **Algoritmos de Regresión**
#
# Es útil para predecir productos continuos. La respuesta se presenta como cantidad. El valor predicho puede usarse para identificar la relación lineal entre atributos.
#
# Ejemplos:
#
# - Precios de vivienda. Estimar precios de inmuebles considerando variables como dimensión de propiedad, tamaño de construcción, pisos, recámaras y otras características.
# - Predecir camas hospitalarias necesarias. Una oficina o secretaría de salud podría predecir con base a su histórico la cantidad de camas y doctores que serán necesarios el próximo año para atender a la demanda de la población. Un avance que pudiéramos llevar allá es con la cantidad de mujeres embarazadas.
# - Identificar las cervezas que necesitarás en tu inventario. Predecir la cantidad de inventarios es una de las aplicaciones más usadas en el sector retail.
#
# ## 2.4.3 **Técnicas**
#
# **Regresión lineal:**
# La regresión lineal es un método de modelado estadístico que se utiliza para predecir o estimar el valor de una variable dependiente continua en función de una o más variables independientes. El objetivo es encontrar la mejor línea recta que se ajuste a los datos y minimice la diferencia entre los valores observados y los valores predichos. Se asume una relación lineal entre las variables y se utilizan técnicas como el método de los mínimos cuadrados para calcular los coeficientes de la línea recta. La regresión lineal es ampliamente utilizada en diversos campos para realizar predicciones y analizar relaciones entre variables.
#
# **Regresión no lineal:**
# La regresión no lineal es similar a la regresión lineal, pero permite modelar relaciones no lineales entre las variables dependientes e independientes. En lugar de ajustarse a una línea recta, los modelos de regresión no lineal se ajustan a curvas más complejas, como polinomios, exponenciales, logaritmos, entre otros. Estos modelos pueden capturar relaciones más flexibles y pueden ser más adecuados cuando los datos muestran patrones no lineales. La regresión no lineal se utiliza en diversas áreas, como ciencias de la salud, economía, física, entre otras, para modelar y predecir fenómenos más complejos.
#
# **Regresión Logística:**
# La regresión logística es un algoritmo de aprendizaje supervisado que se utiliza para predecir la probabilidad de pertenencia a una clase específica en función de variables predictoras. En este caso, el modelo se entrena con datos de juegos existentes (género y plataforma) y su éxito o no éxito en términos de ventas globales. Luego, se utiliza para predecir si una nueva idea de juego será exitosa o no, en función de su género y plataforma.
#
# **Máquinas de soporte de vectores (support vector machines):**
# Las máquinas de vectores de soporte son un algoritmo de aprendizaje supervisado utilizado tanto para clasificación como para regresión. El objetivo principal de las SVM es encontrar el hiperplano óptimo que maximiza el margen entre las clases en un espacio dimensional más alto. Utiliza puntos de datos de entrenamiento llamados vectores de soporte para definir el hiperplano y clasificar nuevas instancias en una de las dos clases. Las SVM son conocidas por su capacidad para manejar conjuntos de datos complejos y de alta dimensión, y han demostrado ser efectivas en aplicaciones como reconocimiento de imágenes, clasificación de texto y detección de anomalías.
#
# **_Redes Neuronales Artificiales_:**
# Las redes neuronales son modelos de aprendizaje automático inspirados en el funcionamiento del cerebro humano. Están compuestas por múltiples capas de neuronas artificiales interconectadas, donde cada neurona realiza cálculos y transmite señales a través de conexiones ponderadas. Estas redes pueden aprender y adaptarse a partir de datos para realizar tareas de clasificación, regresión o reconocimiento de patrones. Cada capa de neuronas procesa y extrae características de los datos de entrada, lo que permite un aprendizaje profundo y la detección de relaciones complejas. Las redes neuronales se utilizan en una amplia gama de aplicaciones, como reconocimiento de imágenes, procesamiento del lenguaje natural, análisis de datos y más.
#
# **Aprendizaje profundo (deep learning):**
# El aprendizaje profundo es una rama del aprendizaje automático que se basa en redes neuronales profundas. Utiliza algoritmos de aprendizaje automático para entrenar redes neuronales con múltiples capas ocultas, lo que permite un aprendizaje jerárquico de características complejas en los datos. El aprendizaje profundo se caracteriza por su capacidad para extraer y aprender representaciones de alto nivel de los datos de entrada, lo que puede conducir a un rendimiento mejorado en tareas de reconocimiento, clasificación, generación de contenido y toma de decisiones. Es especialmente efectivo cuando se trabaja con grandes conjuntos de datos y problemas complejos. El aprendizaje profundo ha impulsado avances significativos en áreas como el procesamiento de imágenes y el procesamiento del lenguaje natural.
#
# **Bosques aleatorios (random forests):**
# Los bosques aleatorios son un conjunto de árboles de decisión que trabajan juntos para realizar clasificación o regresión. Cada árbol se entrena en una muestra aleatoria de datos y realiza una votación para determinar la clasificación final o el valor de regresión. Los bosques aleatorios tienen la capacidad de manejar grandes conjuntos de datos con alta dimensionalidad.
#
#
# Source: https://www.ibm.com/docs/es/spss-modeler/saas?topic=mining-types-models
#
# ---

# %% [markdown]
# # 3. **Descripcion del Tema**
#
# ## 3.1 **Planteamiento del problema**
#
# La educación superior tiene entre sus compromisos principales la formación de capital humano calificado, para poder desarrollar habilidades en base a los actuales avances científicos y tecnológicos, por la razón de tener una calidad en su enseñanza. Por lo tanto, el sistema educativo tiene la obligación de realizar actividades de investigación de vanguardia, a través de las problemáticas y/o necesidades de la sociedad, que permita a Instituciones Educativas tener las herramientas y metodologías necesarias para llevar a cabo un proceso de enseñanza y aprendizaje de calidad. Así que, una de las problemáticas que se tiene en la formación educativa de los estudiantes en la actualidad, es la decersion escolar  en  las  escuelas  e  instituciones  públicas educativas  de nivel superior.
#
# De tal manera, es necesario implementar  herramientas que ayuden a medir de forma cuantitativa las razones de la decersion escolar en la educación, y de forma paralela, el uso de metodologías didácticas que ayuden al desarrollo de estrategias de aprendizaje en la parte teórica y práctica de forma interactiva; y den como resultado adecuar y orientar el proceso de enseñanza y aprendizaje; que comprometa al profesor y al estudiante en la formación integral y permite evitar que el estudiante decida concluir sus estudios y su formación profesional.
#
#
# ## 3.2 **Tema de investigación**
#
# **Análisis de la correlación entre factores predictivos y la deserción escolar en la educación superior mediante modelos de Red Neuronal Artificial.**
#
# Este estudio busca identificar y comprender cómo variables académicas, socioeconómicas y demográficas, se relacionan con la deserción estudiantil en la educación superior. A través del uso de técnicas de aprendizaje automático, específicamente redes neuronales artificiales, se pretende construir un modelo predictivo capaz de anticipar el riesgo de abandono académico y aportar información útil para el diseño de estrategias de retención estudiantil.
#
# ## 3.3  **Pregunta de investigación**
#
# ¿Cuál es la relación entre los factores académicos, socioeconómicos y demográficos analizados en el dataset y la deserción escolar en la educación superior, y cómo pueden estos factores ser utilizados por un modelo de RNA para predecir el riesgo de abandono estudiantil?
#
# ## 3.4 **Objetivo General**
#
# Analizar los factores académicas, socioeconómicas y demográficas que influyen en la deserción estudiantil en la educación superior, con el fin de identificar patrones predictivos que permitan diseñar estrategias de retención efectivas.
#
# ## 3.5 **Objetivos particulares**
#
# - Determinar las relaciónes académicas, socioeconómicas y demográficas del estudiante y su probabilidad de deserción.
#
# - Construir un modelo predictivo que permita identificar estudiantes en riesgo de abandono académico utilizando técnicas de regresión y/o clasificación.
#
# ## **3.6 Justificación**
#
# La deserción escolar en la educación superior representa uno de los principales desafíos para las instituciones académicas, gobiernos y la sociedad en general. Este fenómeno no solo implica una pérdida de recursos económicos y humanos, sino también limita las oportunidades de desarrollo personal y profesional de los estudiantes afectados. Si bien existen múltiples causas que inciden en el abandono académico, las características individuales y contextuales de los estudiantes tienen un peso significativo en la permanencia o no dentro del sistema educativo.
#
# Dentro de estas características, el estado civil puede reflejar responsabilidades familiares o sociales que interfieren con la continuidad académica. Asimismo, la modalidad de ingreso puede dar cuenta de diferencias en los niveles de preparación, motivación y contexto de ingreso al sistema universitario. Por otro lado, la modalidad de asistencia (diurna o nocturna) puede estar asociada con factores laborales o personales que afectan el rendimiento y la permanencia del estudiante.
#
# El presente estudio se justifica en la necesidad de comprender cómo estas variables individuales, junto con factores académicos y sociodemográficos, se relacionan con la deserción en la educación superior. Al identificar patrones o correlaciones entre dichas variables y el abandono académico, es posible desarrollar modelos predictivos que permitan anticipar el riesgo de deserción, facilitando la implementación de estrategias focalizadas de acompañamiento y retención.
#
# ---

# %% [markdown]
# # 4. **Metodología de Desarrollo**
#
# Para realizar un Análisis Exploratorio de Datos (AED) y construir un Modelo de Datos Predictivo que permita identificar los factores asociados a la deserción escolar en la educación superior, se propone desarrollar las siguientes tareas:
#
# #### Definición de la(s) _Variable(s) Objetivo(s)._
#    - Definir claramente la variable objetivo del estudio: Deserción (Sí / No).
#    - Seleccionar las variables independientes de interés: Estado civil, asistencia diurna/nocturna, modalidad de ingreso, calificación previa, nacionalidad, orden de aplicación, escolaridad de los padres, entre otras.
#
# ---
#
# #### Data Clean:
#    - Cargar los datos desde la fuente institucional.
#    - Preprocesar datos para asegurar integridad y consistencia de los datos.
#    - Eliminar  variables irrelevantes que no aporten a la predicción de la deserción.
#    - Imputar valores faltantes en variables relevantes.
#    - Estandarizar y limpiar nombres de atributos para facilitar el análisis.
#
# ---
#
# #### Análisis Exploratorio de Datos (AED)
#
# Explorar la relación entre la variable objetivo (**deserción**) y las variables independientes. Se realizarán:
#
# - Análisis de **correlación entre el estado civil y la tasa de deserción**.
# - **Distribución de deserción por modalidad de asistencia** (diurna/nocturna).
# - **Tendencias de deserción por modalidad de ingreso** y orden de aplicación.
# - **Relación entre calificaciones previas y abandono**.
# - **Deserción según nivel educativo de los padres**.
# - **Visualizaciones interactivas** (mapas de calor, histogramas, gráficos de barras, etc.).
#
# ---
#
# #### Construcción de un Modelo Predictivo Supervisado
#
# Se entrenará un **modelo de RNA** para **predecir la probabilidad de deserción estudiantil**, utilizando el algoritmo de retropropagación del error (**backpropagation**) como método de aprendizaje supervisado.
#
# #### Red Neuronal Artificial (RNA)
#
# Dado que la variable de salida es categórica (**deserta / no deserta**), se implementará una red neuronal multicapa (**MLP**) con las siguientes características:
#
# - Capa de entrada con variables relevantes (demográficas, académicas, familiares, etc.)
# - Una o más **capas ocultas** con funciones de activación no lineales (ReLU, sigmoid, etc.)
# - Capa de salida con activación sigmoide para clasificación binaria
# - **Backpropagation** como método de ajuste de pesos, mediante **descenso del gradiente**
#
# Este modelo es adecuado para capturar **relaciones no lineales y patrones complejos** en los datos de deserción estudiantil.
#
# ---
#
# #### Evaluación del Modelo
#
# El rendimiento del modelo de red neuronal se evaluará utilizando métricas comunes en clasificación binaria:
#
# - **Accuracy (exactitud)**
# - **Precisión**, **Recall (sensibilidad)** y **F1-score**
# - **Curva ROC y AUC**
# - **Matriz de confusión**
#
# ---
#
# #### Implementación del Modelo
#
# - Despliegue de un **prototipo funcional** de sistema de alerta temprana, basado en RNA.
# - **Integración con dashboards institucionales** para permitir el seguimiento visual de casos de riesgo.
#
# ---
#
# #### Retroalimentación y Ajustes
#
# - Análisis de errores y revisión de predicciones incorrectas.
# - Ajuste de **hiperparámetros** de la red neuronal (tasa de aprendizaje, número de neuronas, número de capas, etc.).
# - Aplicación de técnicas de **selección de características** (_feature selection_) para mejorar la generalización.
# - **Reentrenamiento y validación cruzada** para asegurar un desempeño robusto y evitar el sobreajuste.
#
# ---

# %% [markdown]
# ## 4.1 **Definición de la(s) Variable(s) Objetivo(s)**
#
# **El objetivo es clasificar el estado de deserción escolar de los estudiantes** (dropout, enrolled, graduate), utilizando variables académicas, demográficas y socioeconómicas, para identificar los factores que más influyen en la permanencia o abandono de los estudios superiores.
#
# La **variable objetivo** será determinar si un estudiante deserta, continúa inscrito o se gradúa al final del periodo normal del curso, definida en el atributo **'Target'**. Para alcanzar este objetivo, se utilizarán las siguientes variables principales:
#
# **Estado civil:** Puede influir en la permanencia escolar, ya que diferentes situaciones personales pueden afectar el compromiso académico.
#
# **Modalidad y orden de aplicación:** Reflejan el tipo de acceso y preferencia del estudiante por el curso, lo que puede estar relacionado con su motivación y riesgo de deserción.
#
# **Curso y modalidad de asistencia (diurna/nocturna):** Permiten analizar si ciertos programas o turnos presentan mayor riesgo de abandono.
#
# **Nivel educativo previo y calificaciones:** El historial académico previo y el rendimiento en el proceso de admisión pueden ser indicadores clave de éxito o riesgo de deserción.
#
# **Nacionalidad y características familiares:** Factores como la nacionalidad, el nivel educativo y ocupación de los padres pueden influir en el apoyo y recursos disponibles para el estudiante.
#
# **Condiciones socioeconómicas:** Variables como ser desplazado, necesidades educativas especiales, deudor, becario, y si las colegiaturas están al corriente, permiten identificar barreras económicas o sociales.
#
# **Género y edad al ingreso:** Factores demográficos que pueden estar asociados a diferentes patrones de permanencia o abandono.
#
# **Desempeño académico en los primeros semestres:** Número de unidades curriculares inscritas, aprobadas, promedio de calificaciones y evaluaciones en los primeros semestres son predictores directos del riesgo de deserción.
#
# **Variables macroeconómicas:** Tasas de desempleo, inflación y PIB pueden contextualizar el entorno económico que afecta a los estudiantes.
#
# Otras variables relevantes pueden incluir la internacionalización, la tenencia de becas, y la presencia de necesidades educativas especiales, dependiendo de la disponibilidad y relevancia para el análisis.
#
# ---

# %% [markdown]
# # 5. **Data Clean**
#
# ## 5.1 **Descripción de los datos**
#
# En este proyecto se cuenta con un conjunto de datos obtenidos a través de UC Irvine Machine Learning Repositor:
# - https://archive.ics.uci.edu/dataset/697/predict+students+dropout+and+academic+success
#
# Los data sets están en formato CSV:
# - data.csv
#
# La información que contiene los archivos CSV es la siguiente:
#
# - Atributos:
#   - **Marital Status**: Estado civil del estudiante. Valores: 1 (soltero), 2 (casado), 3 (viudo), 4 (divorciado), 5 (unión de hecho), 6 (separado legalmente).
#
#   - **Application mode**: Modalidad de aplicación a la universidad. Indica el tipo de proceso de admisión por el que ingresó el estudiante (varios códigos según la normativa y tipo de contingente).
#
#   - **Application order**: Orden de preferencia de la carrera al momento de aplicar (0 = primera opción, hasta 9 = última opción).
#
#   - **Course**: Carrera o programa académico en el que se inscribió el estudiante (códigos numéricos para cada carrera).
#
#   - **Daytime/evening attendance**: Modalidad de asistencia. 1 = diurna, 0 = nocturna.
#
#   - **Previous qualification**: Nivel educativo previo alcanzado antes de ingresar (códigos para secundaria, licenciatura, maestría, etc.).
#
#   - **Previous qualification (grade)**: Calificación obtenida en la titulación previa (escala de 0 a 200).
#
#   - **Nacionality**: Nacionalidad del estudiante (códigos para cada país).
#
#   - **Mother's qualification / Father's qualification**: Nivel educativo alcanzado por la madre/padre (códigos para secundaria, licenciatura, maestría, etc.).
#
#   - **Mother's occupation / Father's occupation**: Ocupación de la madre/padre (códigos para diferentes profesiones y oficios).
#
#   - **Admission grade**: Calificación de admisión a la universidad (escala de 0 a 200).
#
#   - **Displaced**: Si el estudiante es desplazado (1 = sí, 0 = no).
#
#   - **Educational special needs**: Si el estudiante tiene necesidades educativas especiales (1 = sí, 0 = no).
#
#   - **Debtor**: Si el estudiante tiene deudas con la institución (1 = sí, 0 = no).
#
#   - **Tuition fees up to date**: Si el estudiante está al corriente con el pago de colegiaturas (1 = sí, 0 = no).
#
#   - **Gender**: Género del estudiante (1 = masculino, 0 = femenino).
#
#   - **Scholarship holder**: Si el estudiante es becario (1 = sí, 0 = no).
#
#   - **Age at enrollment**: Edad del estudiante al momento de la inscripción.
#
#   - **International**: Si el estudiante es internacional (1 = sí, 0 = no).
#
#   - **Curricular units 1st sem (credited/enrolled/evaluations/approved/grade/without evaluations)**: Información académica del primer semestre: número de materias acreditadas, inscritas, evaluaciones realizadas, aprobadas, promedio de calificaciones (0-20), y materias sin evaluación.
#
#   - **Curricular units 2nd sem (credited/enrolled/evaluations/approved/grade/without evaluations)**: Información académica del segundo semestre, igual que el primer semestre.
#
#   - **Unemployment rate**: Tasa de desempleo (%) en el contexto del estudiante.
#
#   - **Inflation rate**: Tasa de inflación (%) en el contexto del estudiante.
#
#   - **GDP**: Producto Interno Bruto (PIB) del país o región.
#
#   - **Target**: Variable objetivo. Clasificación del estado final del estudiante: 'dropout' (desertó), 'enrolled' (inscrito), 'graduate' (graduado).
#
# </small>
#
# Diagrama Entidad Relacion
#
# <p align="center">
#   <img src="../img/Proyecto_Final.png" width="600" height="400">
# </p>
#
# ---

# %% [markdown]
# ## 5.2 **Carga de Datos**

# %%
# Instalación de módulos
# !pip install pandas
# !pip install matplotlib
# !pip install networkx
# !pip install -U scikit-learn
# Instalar el paquete ucimlrepo
# !pip install ucimlrepo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# DEPRECATION: Loading egg at c:\programdata\anaconda3\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# DEPRECATION: Loading egg at c:\programdata\anaconda3\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
# Importar solo las librerías necesarias para análisis de datos y modelo de red neuronal artificial con backpropagation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
from ucimlrepo import fetch_ucirepo

# Descargar el dataset desde UCI
predict_students_dropout_and_academic_success = fetch_ucirepo(id=697)

# Extraer los datos en DataFrames de pandas
df = predict_students_dropout_and_academic_success.data.original

# %% [markdown]
# ## 5.3 **Preprocesar los datos**

# %% [markdown]
# ###  Visualización del dataframe

# %% [markdown]
# A continuación, se visualiza el DataFrame resultante:

# %%
#DataFrames
df.head()
# Out:
#    Marital Status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %% [markdown]
# ### Revisión de nombres de columnas

# %% [markdown]
# Estandarizar y limpiar los nombres de los atributos para evitar errores por espacios, mayúsculas/minúsculas o caracteres especiales.

# %%
# Estandarizar y limpiar los nombres de las columnas del DataFrame
df.columns = (
    df.columns.str.strip()                # Elimina espacios al inicio/final
             .str.lower()                 # Convierte a minúsculas
             .str.replace(' ', '_')       # Reemplaza espacios por guiones bajos
             .str.replace('/', '_')       # Reemplaza diagonales por guiones bajos
             .str.replace('(', '')        # Elimina paréntesis izquierdos
             .str.replace(')', '')        # Elimina paréntesis derechos
             .str.replace("'", '')        # Elimina comillas simples
             .str.replace('.', '')        # Elimina puntos
)

df.head()
# Out:
#    marital_status  application_mode  application_order  course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    daytime_evening_attendance  previous_qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    previous_qualification_grade  nacionality  mothers_qualification  \
# 0                         122.0            1                     19
# 1                         160.0            1                      1
# ...

# %% [markdown]
# ### Imputar de valores faltantes

# %% [markdown]
# Rellenar o eliminar los valores nulos (NaN) en las variables relevantes, usando la media, mediana, moda o un valor específico según el contexto.

# %%
# Imputación de valores faltantes en df

# Para variables numéricas: rellenar con la media
num_cols = df.select_dtypes(include=['float64', 'int64']).columns
df[num_cols] = df[num_cols].fillna(df[num_cols].mean())

# Para variables categóricas: rellenar con la moda
cat_cols = df.select_dtypes(include=['object']).columns
for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# Verificar que no queden valores nulos
print(df.isnull().sum())
# Out:
# marital_status                                  0
# application_mode                                0
# application_order                               0
# course                                          0
# daytime_evening_attendance                      0
# previous_qualification                          0
# previous_qualification_grade                    0
# nacionality                                     0
# mothers_qualification                           0
# fathers_qualification                           0
# mothers_occupation                              0
# fathers_occupation                              0
# admission_grade                                 0
# displaced                                       0
# educational_special_needs                       0
# debtor                                          0
# tuition_fees_up_to_date                         0
# gender                                          0
# scholarship_holder                              0
# ...

# %% [markdown]
# ### Conversión de tipos de datos

# %% [markdown]
# Asegurar que cada columna tenga el tipo de dato correcto (numérico, categórico, booleano, etc.).

# %%
# Convertir columnas numéricas a tipo numérico (int o float)
for col in num_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Convertir columnas categóricas a tipo 'category'
for col in cat_cols:
    df[col] = df[col].astype('category')

# Ejemplo: convertir columnas booleanas si aplica (0/1 a bool)
bool_cols = ['displaced', 'educational_special_needs', 'debtor', 'tuition_fees_up_to_date',
             'gender', 'scholarship_holder', 'international']
for col in bool_cols:
    if col in df.columns:
        df[col] = df[col].astype(bool)

# Verificar tipos de datos resultantes
print(df.dtypes)
# Out:
# marital_status                                     int64
# application_mode                                   int64
# application_order                                  int64
# course                                             int64
# daytime_evening_attendance                         int64
# previous_qualification                             int64
# previous_qualification_grade                     float64
# nacionality                                        int64
# mothers_qualification                              int64
# fathers_qualification                              int64
# mothers_occupation                                 int64
# fathers_occupation                                 int64
# admission_grade                                  float64
# displaced                                           bool
# educational_special_needs                           bool
# debtor                                              bool
# ...

# %% [markdown]
# ### Revisión de valores

# %% [markdown]
# Detectar y tratar valores fuera de rango o inconsistentes.

# %%
# Definir umbrales razonables para las variables 
limites = {
    'age_at_enrollment': (15, 70),  # Edad universitaria típica
    'admission_grade': (0, 200),
    'previous_qualification_grade': (0, 200),
    'curricular_units_1st_sem_grade': (0, 20),
    'curricular_units_2nd_sem_grade': (0, 20),
    'unemployment_rate': (0, 100),
    'inflation_rate': (-10, 100),
    'gdp': (-100, 1000)
}

# Corregir valores fuera de rango: reemplazar por NaN y luego imputar con la media de la columna
for col, (min_val, max_val) in limites.items():
    if col in df.columns:
        outliers = ~df[col].between(min_val, max_val)
        if outliers.any():
            print(f"Corrigiendo valores fuera de rango en '{col}': {df.loc[outliers, col].values}")
            df.loc[outliers, col] = np.nan
            df[col] = df[col].fillna(df[col].mean())

# Revisar valores únicos en variables categóricas para detectar inconsistencias
for col in cat_cols:
    print(f"Valores únicos en '{col}': {df[col].unique()}")

# Ejemplo: estandarizar valores de la variable objetivo 'target'
if 'target' in df.columns:
    df['target'] = df['target'].str.capitalize().replace({'Dropout': 'Dropout', 'Graduate': 'Graduate', 'Enrolled': 'Enrolled'})

# Verificar si quedan valores fuera de rango
for col, (min_val, max_val) in limites.items():
    if col in df.columns:
        assert df[col].between(min_val, max_val).all(), f"Valores fuera de rango aún presentes en {col}"

print("Revisión y corrección de valores atípicos completada.")
# Out:
# Valores únicos en 'target': ['Dropout', 'Graduate', 'Enrolled']
# Categories (3, object): ['Dropout', 'Enrolled', 'Graduate']
# Revisión y corrección de valores atípicos completada.

# %% [markdown]
# ### Revisar distribución de variables

# %% [markdown]
# Analizar la frecuencia y valores de cada variable para detectar problemas o decidir si se eliminan.

# %%
# Revisar la distribución de variables categóricas
columnas_categoricas = [
    'marital_status', 'application_mode', 'daytime_evening_attendance', 'nacionality',
    'mothers_qualification', 'fathers_qualification', 'mothers_occupation', 'fathers_occupation',
    'gender', 'scholarship_holder', 'international', 'target'
]
# Filtrar solo las columnas que existen en el DataFrame
columnas_categoricas_existentes = [col for col in columnas_categoricas if col in df.columns]
for col in columnas_categoricas_existentes:
    print(f"Distribución de {col}:")
    print(df[col].value_counts(dropna=False))
    print("\n")

# Revisar la distribución de variables numéricas
columnas_numericas = [
    'application_order', 'course', 'previous_qualification', 'previous_qualification_grade',
    'admission_grade', 'displaced', 'educational_special_needs', 'debtor', 'tuition_fees_up_to_date',
    'age_at_enrollment', 'curricular_units_1st_sem_credited', 'curricular_units_1st_sem_enrolled',
    'curricular_units_1st_sem_evaluations', 'curricular_units_1st_sem_approved',
    'curricular_units_1st_sem_grade', 'curricular_units_1st_sem_without_evaluations',
    'curricular_units_2nd_sem_credited', 'curricular_units_2nd_sem_enrolled',
    'curricular_units_2nd_sem_evaluations', 'curricular_units_2nd_sem_approved',
    'curricular_units_2nd_sem_grade', 'curricular_units_2nd_sem_without_evaluations',
    'unemployment_rate', 'inflation_rate', 'gdp'
]
# Filtrar solo las columnas que existen en el DataFrame
columnas_numericas_existentes = [col for col in columnas_numericas if col in df.columns]
print(df[columnas_numericas_existentes].describe())
# Out:
# Distribución de marital_status:
# marital_status
# 1    3919
# 2     379
# 4      91
# 5      25
# 6       6
# 3       4
# Name: count, dtype: int64
#
#
# Distribución de application_mode:
# application_mode
# 1     1708
# 17     872
# 39     785
# 43     312
# 44     213
# 7      139
# 18     124
# 42      77
# 51      59
# 16      38
# 53      35
# 15      30
# 5       16
# 10      10
# 2        3
# 57       1
# 26       1
# 27       1
# Name: count, dtype: int64
#
#
# Distribución de daytime_evening_attendance:
# daytime_evening_attendance
# 1    3941
# 0     483
# Name: count, dtype: int64
#
#
# Distribución de nacionality:
# nacionality
# 1      4314
# 41       38
# 26       14
# 22       13
# 6        13
# 24        5
# 100       3
# 11        3
# 103       3
# 21        2
# 101       2
# 62        2
# 25        2
# 2         2
# 105       2
# 32        1
# 13        1
# 109       1
# 108       1
# 14        1
# 17        1
# Name: count, dtype: int64
#
#
# ...

# %% [markdown]
# #### Resumen de variables numéricas
#
# | variable                                | count | mean         | std         | min   | 25%    | 50%      | 75%      | max        |
# |------------------------------------------|-------|--------------|-------------|-------|--------|----------|----------|------------|
# | marital_status                          | 4424  | 1.18         | 0.61        | 1     | 1      | 1        | 1        | 6          |
# | application_mode                        | 4424  | 18.67        | 17.48       | 1     | 1      | 17       | 39       | 57         |
# | application_order                       | 4424  | 1.73         | 1.31        | 0     | 1      | 1        | 2        | 9          |
# | course                                  | 4424  | 8856.64      | 2063.57     | 33    | 9085   | 9238     | 9556     | 9991       |
# | daytime_evening_attendance              | 4424  | 0.89         | 0.31        | 0     | 1      | 1        | 1        | 1          |
# | previous_qualification                  | 4424  | 4.58         | 10.22       | 1     | 1      | 1        | 1        | 43         |
# | previous_qualification_grade            | 4424  | 132.61       | 13.19       | 95    | 125    | 133.1    | 140      | 190        |
# | nacionality                             | 4424  | 1.87         | 6.91        | 1     | 1      | 1        | 1        | 109        |
# | mothers_qualification                   | 4424  | 19.56        | 15.60       | 1     | 2      | 19       | 37       | 44         |
# | fathers_qualification                   | 4424  | 22.28        | 15.34       | 1     | 3      | 19       | 37       | 44         |
# | mothers_occupation                      | 4424  | 10.96        | 26.42       | 0     | 4      | 5        | 9        | 194        |
# | fathers_occupation                      | 4424  | 11.03        | 25.26       | 0     | 4      | 7        | 9        | 195        |
# | admission_grade                         | 4424  | 126.98       | 14.48       | 95    | 117.9  | 126.1    | 134.8    | 190        |
# | age_at_enrollment                       | 4424  | 23.27        | 7.59        | 17    | 19     | 20       | 25       | 70         |
# | curricular_units_1st_sem_credited       | 4424  | 0.71         | 2.36        | 0     | 0      | 0        | 0        | 20         |
# | curricular_units_1st_sem_enrolled       | 4424  | 6.27         | 2.48        | 0     | 5      | 6        | 7        | 26         |
# | curricular_units_1st_sem_evaluations    | 4424  | 8.30         | 4.18        | 0     | 6      | 8        | 10       | 45         |
# | curricular_units_1st_sem_approved       | 4424  | 4.71         | 3.09        | 0     | 3      | 5        | 6        | 26         |
# | curricular_units_1st_sem_grade          | 4424  | 10.64        | 4.84        | 0     | 11     | 12.29    | 13.4     | 18.88      |
# | curricular_units_1st_sem_without_evaluations | 4424 | 0.14    | 0.69        | 0     | 0      | 0        | 0        | 12         |
# | curricular_units_2nd_sem_credited       | 4424  | 0.54         | 1.92        | 0     | 0      | 0        | 0        | 19         |
# | curricular_units_2nd_sem_enrolled       | 4424  | 6.23         | 2.20        | 0     | 5      | 6        | 7        | 23         |
# | curricular_units_2nd_sem_evaluations    | 4424  | 8.06         | 3.95        | 0     | 6      | 8        | 10       | 33         |
# | curricular_units_2nd_sem_approved       | 4424  | 4.44         | 3.01        | 0     | 2      | 5        | 6        | 20         |
# | curricular_units_2nd_sem_grade          | 4424  | 10.23        | 5.21        | 0     | 10.75  | 12.2     | 13.33    | 18.57      |
# | curricular_units_2nd_sem_without_evaluations | 4424 | 0.15    | 0.75        | 0     | 0      | 0        | 0        | 12         |
# | unemployment_rate                       | 4424  | 11.57        | 2.66        | 7.6   | 9.4    | 11.1     | 13.9     | 16.2       |
# | inflation_rate                          | 4424  | 1.23         | 1.38        | -0.8  | 0.3    | 1.4      | 2.6      | 3.7        |
# | gdp                                     | 4424  | 0.002        | 2.27        | -4.06 | -1.7   | 0.32     | 1.79     | 3.51       |
#
# ---
#
# #### Resumen de distribución de variables categóricas
#
# | variable                  | valor     | conteo |
# |---------------------------|-----------|--------|
# | displaced                 | True      | 2426   |
# | displaced                 | False     | 1998   |
# | educational_special_needs | False     | 4373   |
# | educational_special_needs | True      | 51     |
# | debtor                    | False     | 3921   |
# | debtor                    | True      | 503    |
# | tuition_fees_up_to_date   | True      | 3896   |
# | tuition_fees_up_to_date   | False     | 528    |
# | gender                    | False     | 2868   |
# | gender                    | True      | 1556   |
# | scholarship_holder        | False     | 3325   |
# | scholarship_holder        | True      | 1099   |
# | international             | False     | 4314   |
# | international             | True      | 110    |
# | target                    | Graduate  | 2209   |
# | target                    | Dropout   | 1421   |
# | target                    | Enrolled  | 794    |

# %% [markdown]
# ### Interpretación del análisis de distribución y criterios para eliminar variables
#
# #### Variables numéricas
#
# **Variables con baja variabilidad o poco informativas:**
# - `daytime_evening_attendance` tiene una media de 0.89 y percentiles 25%, 50%, 75% en 1, lo que indica que casi todos los estudiantes asisten en el turno diurno.
# - `nacionality` muestra una media baja y percentiles iguales a 1, sugiriendo que la mayoría son de la misma nacionalidad.
# - `curricular_units_1st_sem_credited`, `curricular_units_2nd_sem_credited`, `curricular_units_1st_sem_without_evaluations`, `curricular_units_2nd_sem_without_evaluations` tienen medias y percentiles muy bajos, indicando que la mayoría de los estudiantes no tienen créditos o materias sin evaluación en esos semestres.
#
# **Variables con muchos valores únicos o difícil interpretación directa:**
# - `course`, `mothers_occupation`, `fathers_occupation` presentan rangos muy amplios y probablemente muchos valores únicos, lo que dificulta su uso predictivo sin una agrupación previa.
#
# **Variables macroeconómicas:**
# - `unemployment_rate`, `inflation_rate`, `gdp` pueden ser eliminadas si no varían entre estudiantes, ya que no aportan información diferenciadora a nivel individual.
#
# ---
#
# #### Variables categóricas
#
# **Variables con fuerte desbalance:**
# - `educational_special_needs` (solo 51 casos True de 4424) e `international` (solo 110 True) pueden ser poco útiles para el modelo si la clase minoritaria es muy pequeña.
#
# **Variables con baja variabilidad:**
# - Si alguna variable tiene casi todos los valores en una sola categoría (por ejemplo, `gender` si la mayoría es de un solo género), su poder predictivo será bajo.
#
# ---
#
# #### Variables recomendadas para eliminar
#
# - **Por baja variabilidad o desbalance:**
#   `daytime_evening_attendance`, `nacionality`, `educational_special_needs`, `international`, `curricular_units_1st_sem_without_evaluations`, `curricular_units_2nd_sem_without_evaluations`.
# - **Por ser identificadores o difícil interpretación directa:**
#   `course`, `mothers_occupation`, `fathers_occupation` (a menos que se agrupen en categorías relevantes).
# - **Por ser poco relevantes para el objetivo:**
#   `unemployment_rate`, `inflation_rate`, `gdp` (si no varían entre estudiantes).
#
# ---
#
# #### Variables a conservar (más relevantes para la deserción)
#
# - `marital_status`, `application_mode`, `application_order`, `previous_qualification`, `previous_qualification_grade`, `mothers_qualification`, `fathers_qualification`, `admission_grade`, `age_at_enrollment`, `debtor`, `tuition_fees_up_to_date`, `scholarship_holder`, `gender`, `curricular_units_1st/2nd_sem_enrolled`, `curricular_units_1st/2nd_sem_evaluations`, `curricular_units_1st/2nd_sem_approved`, `curricular_units_1st/2nd_sem_grade`, `target`.
#
# Estas variables tienen mayor potencial para explicar patrones de deserción, ya que reflejan características académicas, socioeconómicas y demográficas directamente relacionadas con el fenómeno.
#
# ---

# %% [markdown]
# #### Eliminar variables irrelevantes

# %% [markdown]
# Las siguientes variables **se conservan** para el análisis de deserción escolar, ya que aportan valor predictivo y están directamente relacionadas con la deserción escolar:
#
# - `marital_status`
# - `application_mode`
# - `application_order`
# - `previous_qualification`
# - `previous_qualification_grade`
# - `mothers_qualification`
# - `fathers_qualification`
# - `admission_grade`
# - `age_at_enrollment`
# - `debtor`
# - `tuition_fees_up_to_date`
# - `scholarship_holder`
# - `gender`
# - `curricular_units_1st_sem_enrolled`, `curricular_units_2nd_sem_enrolled`
# - `curricular_units_1st_sem_evaluations`, `curricular_units_2nd_sem_evaluations`
# - `curricular_units_1st_sem_approved`, `curricular_units_2nd_sem_approved`
# - `curricular_units_1st_sem_grade`, `curricular_units_2nd_sem_grade`
# - `target`
#
# Estas variables incluyen información académica, socioeconómica y demográfica relevante para identificar patrones de deserción y construir el modelo predictivo.

# %% [markdown]
# ## 6 **Análisis exploratorio de Datos (AED)**
#
# En el análisis exploratorio se analizan los DataFrames con la información proporcionada en la sección anterior, el propósito es analizar e investigar los conjuntos de datos, resumir sus características principales, identificar relaciones, entender la distribución de la(s) variables(s) objetivo(s) y las variables para conseguir el objetivo del proyecto.
#
# Se define a realizar lo siguiente:
#
# #### **Análisis univariado**
# - **Distribución de la variable objetivo** (`target`): ¿Cuántos estudiantes desertan, se gradúan o siguen inscritos?
# - **Distribución de variables categóricas**: Estado civil, género, modalidad de ingreso, beca, deudor, etc.
# - **Distribución de variables numéricas**: Edad, calificaciones, número de materias inscritas/aprobadas, etc.
#
# #### **Análisis bivariado**
# - **Relación entre variables independientes y la deserción**:
#   - Tablas de contingencia y gráficos de barras para variables categóricas vs. deserción.
#   - Boxplots o violin plots para comparar variables numéricas según el estado de deserción.
# - **Correlación entre variables numéricas**: Para detectar multicolinealidad y relaciones relevantes.
#
# #### **Análisis multivariado**
# - **Matriz de correlación**: Para identificar relaciones entre variables numéricas.
# - **Mapas de calor**: Visualizar correlaciones y posibles agrupamientos.
#
# #### **Análisis de valores atípicos y datos faltantes**
# - Identificar y tratar outliers en variables numéricas.
# - Analizar patrones de datos faltantes y decidir estrategias de imputación.
#
# #### **Análisis de importancia de variables**
# - Utilizar métodos como árboles de decisión o Random Forest para estimar la importancia de cada variable respecto a la deserción.
#
# #### **Visualizaciones**
# - Histogramas, gráficos de barras, boxplots, pairplots, heatmaps, etc., para entender mejor la distribución y relaciones entre variables.
#
# ---

# %% [markdown]
# ## 6.1 **Análisis sobre las variables categóricas `marital_status` (estado civil) y `gender` (género)**
#
# - **Tablas de frecuencia**: Muestra cuántos estudiantes hay en cada categoría de estado civil y género.
#     - Esto ayuda a entender la distribución de estas variables en el conjunto de datos.
#
# - **Gráficos de barras segmentados por la variable objetivo (`target`)**: Visualiza cómo se distribuye la variable objetivo (por ejemplo, deserción, graduación, inscripción) dentro de cada categoría de estado civil y género.
#    - Permite identificar si ciertas categorías tienen mayor proporción de deserción o graduación.
#
# ---

# %%
# 1. Tablas de frecuencia para marital_status y gender
print("Tabla de frecuencia - marital_status:")
print(df['marital_status'].value_counts())
print("\nTabla de frecuencia - gender:")
print(df['gender'].value_counts())

# 2. Gráficos de barras de marital_status y gender por clase de target
plt.figure(figsize=(12, 5))

# Gráfico de barras para marital_status por target
plt.subplot(1, 2, 1)
sns.countplot(data=df, x='marital_status', hue='target')
plt.title('Estado civil por clase de Target')
plt.xlabel('Estado civil')
plt.ylabel('Cantidad')
plt.legend(title='Target')

# Gráfico de barras para gender por target
plt.subplot(1, 2, 2)
sns.countplot(data=df, x='gender', hue='target')
plt.title('Género por clase de Target')
plt.xlabel('Género (False=Femenino, True=Masculino)')
plt.ylabel('Cantidad')
plt.legend(title='Target')

plt.tight_layout()
plt.show()
# Out:
# Tabla de frecuencia - marital_status:
# marital_status
# 1    3919
# 2     379
# 4      91
# 5      25
# 6       6
# 3       4
# Name: count, dtype: int64
#
# Tabla de frecuencia - gender:
# gender
# False    2868
# True     1556
# Name: count, dtype: int64

# %% [markdown]
# ### 6.1.1 **Información relevante**
#
# - **Estado civil (`marital_status`):**
#   - La gran mayoría de los estudiantes son solteros (valor 1: 3919 de 4424).
#   - Los estudiantes casados (valor 2) son 379.
#   - Otras categorías como divorciado (4), unión de hecho (5), separado legalmente (6) y viudo (3) tienen muy poca representación.
#   - Esto indica que la población estudiantil es predominantemente joven y sin compromisos familiares formales.
#
# - **Género (`gender`):**
#   - Hay más estudiantes de género femenino (`False`: 2868) que masculino (`True`: 1556).
#   - La proporción aproximada es 65% mujeres y 35% hombres.
#
#
# La muestra está compuesta principalmente por estudiantes solteros y mujeres. Este contexto es importante para interpretar los análisis posteriores sobre deserción escolar, ya que el estado civil y el género pueden influir en los patrones de abandono o permanencia.
#
# ---

# %% [markdown]
# ## 6.2 **Análisis de `application_mode` y `application_order` vs `target`**
#
# - **`application_mode`** es una variable que indica  el tipo de ingreso del estudiante a la carrera. Existen diferentes tipos de ingreso:
#     - 1: 1st phase - general contingent (1ª fase - contingente general)
#     - 2: Ordinance No. 612/93 (Ordenanza N.º 612/93)
#     - 5: 1st phase - special contingent (Azores Island) (1ª fase - contingente especial (Islas Azores))
#     - 7: Holders of other higher courses (Titulados de otros cursos superiores)
#     - 10: Ordinance No. 854-B/99 (Ordenanza N.º 854-B/99)
#     - 15: International student (bachelor) (Estudiante internacional (licenciatura))
#     - 16: 1st phase - special contingent (Madeira Island) (1ª fase - contingente especial (Isla Madeira))
#     - 17: 2nd phase - general contingent (2ª fase - contingente general)
#     - 18: 3rd phase - general contingent (3ª fase - contingente general)
#     - 26: Ordinance No. 533-A/99, item b2) (Different Plan) (Ordenanza N.º 533-A/99, apartado b2) (Plan diferente))
#     - 27: Ordinance No. 533-A/99, item b3 (Other Institution) (Ordenanza N.º 533-A/99, apartado b3 (Otra institución))
#     - 39: Over 23 years old (Mayores de 23 años)
#     - 42: Transfer (Transferencia)
#     - 43: Change of course (Cambio de carrera)
#     - 44: Technological specialization diploma holders (Titulados de diploma de especialización tecnológica)
#     - 51: Change of institution/course (Cambio de institución/carrera)
#     - 53: Short cycle diploma holders (Titulados de ciclo corto)
#     - 57: Change of institution/course (International) (Cambio de institución/carrera (Internacional))
#
#
# - **`application_order`** es una variable que indica el orden de preferencia con el que el estudiante aplicó a la carrera. Existen varios modos de aplicación (entre 0 - primera opcion; y 9 - la ultimaopcion).
#
# ---

# %%
# ...existing code...

# Análisis exploratorio de application_mode y application_order
plt.figure(figsize=(14, 6))

# Gráfico de cajas para application_mode vs target
plt.subplot(1, 2, 1)
sns.boxplot(data=df, x='target', y='application_mode', palette='Set2')
plt.title('Distribución de Application Mode por clase de Target')
plt.xlabel('Estado final (Target)')
plt.ylabel('Application Mode')

# Gráfico de violín para application_order vs target
plt.subplot(1, 2, 2)
sns.violinplot(data=df, x='target', y='application_order', palette='Set3', inner='quartile')
plt.title('Distribución de Application Order por clase de Target')
plt.xlabel('Estado final (Target)')
plt.ylabel('Application Order')

plt.tight_layout()
plt.show()

# Interpretación:
print("""
Estos gráficos permiten visualizar cómo varían las modalidades y el orden de aplicación según el estado final del estudiante (deserción, graduación o inscripción).
Patrones diferenciados en estas variables pueden indicar su relevancia para predecir la deserción escolar, fundamentando su inclusión en el modelo de red neuronal.
""")
# ...existing code...
# Out:
# Estos gráficos permiten visualizar cómo varían las modalidades y el orden de aplicación según el estado final del estudiante (deserción, graduación o inscripción).
# Patrones diferenciados en estas variables pueden indicar su relevancia para predecir la deserción escolar, fundamentando su inclusión en el modelo de red neuronal.

# %% [markdown]
# ### 6.2.1 **Interpretación de graficas**
#
# #### Boxplot (izquierda):
# - **Dropout** y **Enrolled** presentan una distribución más amplia de modos de aplicación.
# - **Graduate** tiende a concentrarse en modos de aplicación con valores más bajos, especialmente entre 1 y 20.
# - Hay outliers principalmente en los modos altos (>40), posiblemente modalidades más atípicas o poco utilizadas (como transferencias internacionales).
#
# #### Violin (derecha):
# - **Graduados**: Mayor concentración en las primeras opciones (0 o 1).
# - **Dropout** y **Enrolled**: Distribuciones más dispersas, aunque la mayoría también aplicó en primeras opciones.
# - Algunos **Enrolled** presentan valores extremos de `application_order` (hasta 9), lo que podría indicar menor motivación o baja prioridad por el programa.
#
# ### 6.1.2 información relevante:
#
# - El tipo de aplicación parece estar asociado con la probabilidad de desertar o graduarse.
# - Estudiantes que ingresan por vías ordinarias (modos bajos) tienen más probabilidad de graduarse.
# - Modos de acceso menos comunes o especiales (modos altos) podrían estar más asociados a deserción o matrícula sin graduación.
# - Los estudiantes que priorizaron el programa (orden 0 o 1) tienden a graduarse más.
# - Un orden de aplicación más alto puede estar correlacionado con una mayor probabilidad de deserción.
#
# ---

# %% [markdown]
# ## 6.3 **Análisis de impacto del nivel educativo de los padres y del estudiante en la deserción escolar**
#
# Se analiza el impacto del nivel educativo previo del estudiante, así como la escolaridad de la madre y del padre, en la deserción escolar utilizando gráficos de caja (boxplot) para comparar la distribución de estas variables según el estado final del estudiante (`target`: Dropout, Graduate, Enrolled).
#
# - **Nivel educativo previo vs Target:** El gráfico muestra cómo varía el nivel educativo alcanzado antes de ingresar a la universidad entre los estudiantes que desertan, se gradúan o permanecen inscritos. Se observa que los estudiantes graduados tienden a tener un nivel educativo previo ligeramente mayor en comparación con los desertores.
#
# - **Escolaridad de la madre vs Target:** Se visualiza la relación entre la escolaridad de la madre y el estado final del estudiante. Los estudiantes que se gradúan suelen tener madres con mayor nivel educativo, mientras que los desertores presentan una mayor dispersión y valores más bajos en la escolaridad materna.
#
# - **Escolaridad del padre vs Target:** De manera similar, se analiza la escolaridad del padre en función del estado final. Los graduados tienden a tener padres con mayor escolaridad en comparación con los desertores.
#
# ---

# %%
# Nivel educativo previo vs Target
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
sns.boxplot(data=df, x='target', y='previous_qualification', ax=axes[0])
axes[0].set_title('Nivel educativo previo vs Target')
axes[0].set_xlabel('Target')
axes[0].set_ylabel('Nivel educativo previo')

# Escolaridad de la madre vs Target
sns.boxplot(data=df, x='target', y='mothers_qualification', ax=axes[1])
axes[1].set_title('Escolaridad de la madre vs Target')
axes[1].set_xlabel('Target')
axes[1].set_ylabel('Escolaridad madre')

# Escolaridad del padre vs Target
sns.boxplot(data=df, x='target', y='fathers_qualification', ax=axes[2])
axes[2].set_title('Escolaridad del padre vs Target')
axes[2].set_xlabel('Target')
axes[2].set_ylabel('Escolaridad padre')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6.3.1 **Información relevante**
#
# - **Nivel educativo previo (`previous_qualification`):**
#   - La mayoría de los estudiantes tiene un nivel educativo previo bajo (mediana = 1, percentil 75 = 1), lo que indica que la mayoría ingresó con el nivel mínimo requerido.
#   - Hay algunos casos con niveles previos altos (máximo = 43), pero son minoría (outliers).
#   - No se observan grandes diferencias entre los grupos de `target` en la mediana, pero los graduados tienden a tener algunos valores más altos.
#
# - **Escolaridad de la madre (`mothers_qualification`):**
#   - Media: 19.56, mediana: 19, percentil 75: 37, máximo: 44.
#   - Los estudiantes graduados suelen tener madres con mayor nivel educativo (mediana y percentil 75 más altos).
#   - Los desertores presentan mayor dispersión y valores bajos en la escolaridad materna.
#
# - **Escolaridad del padre (`fathers_qualification`):**
#   - Media: 22.28, mediana: 19, percentil 75: 37, máximo: 44.
#   - Los graduados tienden a tener padres con mayor escolaridad en comparación con los desertores.
#   - La dispersión es similar a la escolaridad materna.
#
#
# Un mayor nivel educativo de los padres y del propio estudiante está asociado a una mayor probabilidad de graduación y menor riesgo de deserción. Los estudiantes que desertan tienden a provenir de familias con menor escolaridad.
#
# ---

# %% [markdown]
# ## 6.4 **Análisis cruzado: deudas vs tasa de deserción**
#
# En este análisis se examina la relación entre la condición de deudor del estudiante (`debtor`) y su estado final en la universidad (`target`: Dropout, Graduate, Enrolled).
#
# Primero, se visualiza la cantidad de estudiantes con y sin deudas segmentados por su estado final mediante un gráfico de barras. Esto permite identificar si existe una mayor proporción de deserción entre quienes tienen deudas.
#
# Luego, se calcula el porcentaje de estudiantes en cada estado (`target`) dentro de los grupos de deudores y no deudores.
#
# ---

# %%
# Análisis cruzado: deudas vs tasa de deserción
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='debtor', hue='target')
plt.title('Deudor vs Estado final (Target)')
plt.xlabel('¿Tiene deudas? (False=No, True=Sí)')
plt.ylabel('Cantidad')
plt.legend(title='Target')
plt.show()

# Porcentaje de deserción según deudor
deuda_desercion = pd.crosstab(df['debtor'], df['target'], normalize='index') * 100
print(deuda_desercion)
# Out:
# target    Dropout   Enrolled   Graduate
# debtor
# False   28.283601  17.954603  53.761795
# True    62.027833  17.892644  20.079523

# %% [markdown]
# ### 6.4.1 **Información relevante**
#
# - **Distribución de estudiantes según deudas:**
#   - El 89% de los estudiantes **no tienen deudas** (`debtor=False`, 3921 casos).
#   - El 11% **sí tienen deudas** (`debtor=True`, 503 casos).
#
# - **Relación entre deudas y estado final (target):**
#   - Entre los estudiantes **sin deudas**:
#     - 28.3% desertaron (`Dropout`)
#     - 17.9% siguen inscritos (`Enrolled`)
#     - 53.8% se graduaron (`Graduate`)
#   - Entre los estudiantes **con deudas**:
#     - 62.0% desertaron
#     - 17.9% siguen inscritos
#     - 20.1% se graduaron
#
#
#   Tener deudas está fuertemente asociado a una mayor probabilidad de deserción escolar. Más del 60% de los estudiantes con deudas desertan, mientras que solo el 28% de los que no tienen deudas lo hacen. Además, la tasa de graduación es mucho menor en quienes tienen deudas (20%) comparado con quienes no tienen (54%). Por lo tanto, la condición de deudor es un factor de riesgo importante para la deserción estudiantil.
#
#   ---

# %% [markdown]
# ## 6.5 **Análisis agrupados por target para calificaciones y edad de ingreso**
#
# En este análisis se examina la distribución de variables académicas y demográficas agrupadas por el estado final del estudiante (`target`: Dropout, Graduate, Enrolled). Se utilizan histogramas y boxplots para comparar:
#
# - **Calificación previa** (`previous_qualification_grade`): Se visualiza cómo varían las calificaciones obtenidas antes de ingresar a la universidad entre los diferentes grupos de target.
#
# - **Calificación de admisión** (`admission_grade`): Se analiza la distribución de las calificaciones obtenidas en el proceso de admisión, permitiendo identificar diferencias entre quienes desertan, se gradúan o permanecen inscritos.
#
# - **Edad de ingreso** (`age_at_enrollment`): Se compara la edad al momento de la inscripción según el estado final del estudiante.
#
# Los histogramas muestran la frecuencia de cada valor en las variables, diferenciando por grupo de target, mientras que los boxplots permiten observar la mediana, los cuartiles y posibles valores atípicos en cada grupo. Esto puede identificar patrones y diferencias relevantes en el rendimiento académico previo y la edad de ingreso asociados a la deserción, graduación o permanencia.

# %%
# Histogramas y boxplots agrupados por target para calificaciones y edad de ingreso
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# previous_qualification_grade
sns.histplot(data=df, x='previous_qualification_grade', hue='target', multiple='stack', ax=axes[0,0])
axes[0,0].set_title('Histograma: Calificación previa por Target')
sns.boxplot(data=df, x='target', y='previous_qualification_grade', ax=axes[1,0])
axes[1,0].set_title('Boxplot: Calificación previa por Target')

# admission_grade
sns.histplot(data=df, x='admission_grade', hue='target', multiple='stack', ax=axes[0,1])
axes[0,1].set_title('Histograma: Calificación de admisión por Target')
sns.boxplot(data=df, x='target', y='admission_grade', ax=axes[1,1])
axes[1,1].set_title('Boxplot: Calificación de admisión por Target')

# age_at_enrollment
sns.histplot(data=df, x='age_at_enrollment', hue='target', multiple='stack', ax=axes[0,2])
axes[0,2].set_title('Histograma: Edad de ingreso por Target')
sns.boxplot(data=df, x='target', y='age_at_enrollment', ax=axes[1,2])
axes[1,2].set_title('Boxplot: Edad de ingreso por Target')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6.5.1 **Información relevante**
#
# **Calificación previa (`previous_qualification_grade`):**
# - Los estudiantes graduados tienden a tener calificaciones previas ligeramente más altas que los desertores y los inscritos. Los desertores presentan mayor dispersión y más casos con calificaciones bajas.
# - Un mejor desempeño académico previo está asociado a una mayor probabilidad de graduación y menor riesgo de deserción.
#
# **Calificación de admisión (`admission_grade`):**
# - Los graduados suelen tener calificaciones de admisión más altas. Los desertores y los inscritos muestran una mayor proporción de calificaciones bajas.
# - Una calificación de admisión más alta es un factor protector contra la deserción.
#
# **Edad de ingreso (`age_at_enrollment`):**
# - Los graduados suelen ingresar a menor edad (mediana más baja). Los desertores presentan mayor dispersión y más casos de ingreso a edades avanzadas.
# -  Ingresar a la universidad a una edad mayor se asocia con mayor riesgo de deserción, mientras que los estudiantes más jóvenes tienen mayor probabilidad de graduarse.
#
#
# Un mejor desempeño académico previo, una mayor calificación de admisión y un ingreso a menor edad están asociados a una mayor probabilidad de graduación y menor riesgo de deserción. Estos factores permiten identificar estudiantes en riesgo.
#
# ---

# %% [markdown]
# ## 6.6 **Análisis de comparación de carga académica, calificaciones y aprobaciones por semestre**
#
# El objetivo del análisis es para identificar diferencias en la carga académica, el rendimiento y la aprobación de materias entre los estudiantes que desertan, se gradúan o permanecen inscritos, facilitando la detección de patrones o brechas relevantes en el desempeño académico según el estado final.

# %%
# Comparación de carga académica, calificaciones y aprobaciones por semestre
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# 1er semestre
sns.boxplot(data=df, x='target', y='curricular_units_1st_sem_enrolled', ax=axes[0,0])
axes[0,0].set_title('Materias inscritas 1er sem vs Target')
sns.boxplot(data=df, x='target', y='curricular_units_1st_sem_approved', ax=axes[0,1])
axes[0,1].set_title('Materias aprobadas 1er sem vs Target')
sns.boxplot(data=df, x='target', y='curricular_units_1st_sem_grade', ax=axes[0,2])
axes[0,2].set_title('Promedio 1er sem vs Target')

# 2do semestre
sns.boxplot(data=df, x='target', y='curricular_units_2nd_sem_enrolled', ax=axes[1,0])
axes[1,0].set_title('Materias inscritas 2do sem vs Target')
sns.boxplot(data=df, x='target', y='curricular_units_2nd_sem_approved', ax=axes[1,1])
axes[1,1].set_title('Materias aprobadas 2do sem vs Target')
sns.boxplot(data=df, x='target', y='curricular_units_2nd_sem_grade', ax=axes[1,2])
axes[1,2].set_title('Promedio 2do sem vs Target')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6.6.1 **Información relevante**
#
# ### Información relevante del análisis de carga académica, calificaciones y aprobaciones por semestre
#
# **Materias inscritas y aprobadas:**
# - **Primer semestre:**
#   - **Inscritas:** Media ≈ 6.3, mediana = 6, la mayoría de estudiantes inscriben entre 5 y 7 materias.
#   - **Aprobadas:** Media ≈ 4.7, mediana = 5, pero con alta dispersión (algunos no aprueban ninguna, otros aprueban todas).
#   - Los estudiantes graduados tienden a inscribir y aprobar más materias en el primer semestre que los desertores. Los desertores presentan mayor variabilidad y más casos con pocas materias aprobadas.
#
# - **Segundo semestre:**
#   - **Inscritas:** Media ≈ 6.2, mediana = 6, similar al primer semestre.
#   - **Aprobadas:** Media ≈ 4.4, mediana = 5, con dispersión similar.
#   - El patrón se repite: los graduados inscriben y aprueban más materias, mientras que los desertores tienden a inscribir y aprobar menos.
#
# - **Promedio de calificaciones:**
#     - **Primer semestre:** Media ≈ 10.6, mediana ≈ 12.3, 75% de los estudiantes tienen promedio ≤ 13.4.
#     - **Segundo semestre:** Media ≈ 10.2, mediana ≈ 12.2, 75% ≤ 13.3.
#     - Los graduados presentan promedios más altos y menor dispersión. Los desertores tienen promedios más bajos y mayor variabilidad, con casos extremos de promedios muy bajos.
#
# - **Materias acreditadas y sin evaluación:**
#     - La mayoría de los estudiantes no acredita materias por equivalencia ni tiene materias sin evaluación (mediana = 0 en ambos casos).
#
#
# - Los estudiantes que inscriben, aprueban más materias y obtienen mejores promedios en los primeros semestres tienen mayor probabilidad de graduarse.
# - Los desertores suelen tener menor carga académica, menos materias aprobadas y promedios más bajos, lo que indica dificultades académicas tempranas.
# - La dispersión y presencia de outliers en los desertores sugiere que algunos abandonan tras un bajo desempeño, mientras que otros pueden inscribir muchas materias pero no aprobarlas.
#
# Estos indicadores permiten identificar estudiantes en riesgo de deserción desde los primeros semestres y orientar intervenciones tempranas.

# %% [markdown]
# ## 6.7 **Análisis de balanceo de clases en la variable objetivo 'target'**

# %%
# Balanceo de clases en la variable objetivo 'target'
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='target')
plt.title('Distribución de clases en Target')
plt.xlabel('Estado final (Target)')
plt.ylabel('Cantidad')
plt.show()

# Mostrar proporciones
print(df['target'].value_counts(normalize=True) * 100)
# Out:
# target
# Graduate    49.932188
# Dropout     32.120253
# Enrolled    17.947559
# Name: proportion, dtype: float64

# %% [markdown]
# ### 6.7.1 **Información relevante**
#
# - **Distribución de clases en la variable objetivo `target`:**
#
#   - **Graduate (Graduado):** 49.9%
#
#   - **Dropout (Desertó):** 32.1%
#
#   - **Enrolled (Inscrito):** 17.9%
#
#   - El conjunto de datos está desbalanceado, con casi la mitad de los estudiantes graduados, un tercio desertores y menos del 20% aún inscritos.
#
#   - Este desbalance se considera al entrenar el modelo de clasificación, ya que puede afectar la capacidad del modelo para predecir correctamente las clases.
#
#   - La mayoría de los estudiantes logra graduarse, pero la tasa de deserción es significativa (más de 1 de cada 3 estudiantes).
#
#   ---

# %% [markdown]
# # 7. **Resultados de AED**
#
# A partir del análisis exploratorio realizado sobre el dataset de estudiantes universitarios, se identifican los siguientes resultados para la selección de variables y el enfoque del modelo de red neuronal para predecir la deserción escolar:
#
# ---
#
# ### **Balanceo de clases en la variable objetivo (`target`)**
#
# - **Distribución:**
#   - Graduate (Graduado): 49.9%
#   - Dropout (Desertó): 32.1%
#   - Enrolled (Inscrito): 17.9%
#
# ---
#
# ### **Factores sociodemográficos relevantes**
# - **Estado civil:**
#   La mayoría de los estudiantes son solteros, pero los casados y otras categorías presentan mayor riesgo de deserción.
# - **Género:**
#   Predominan las mujeres (65%), pero ambos géneros muestran patrones diferenciados de deserción.
#
# ---
#
# ### **Factores académicos y de ingreso**
# - **Modalidad y orden de aplicación:**
#   - Estudiantes que ingresan por vías ordinarias y que priorizan el programa (orden 0 o 1) tienen mayor probabilidad de graduarse.
#   - Modos de acceso menos comunes o con orden de aplicación alto se asocian a mayor deserción.
# - **Nivel educativo previo y calificaciones:**
#   - Un mejor desempeño académico previo y una mayor calificación de admisión están asociados a menor riesgo de deserción.
#   - Los desertores presentan mayor dispersión y más casos con calificaciones bajas.
#
# ---
#
# ### **Factores familiares**
# - **Escolaridad de los padres:**
#   - Los estudiantes cuyos padres tienen mayor nivel educativo presentan menor riesgo de deserción.
#   - La baja escolaridad de los padres es un factor de riesgo importante.
#
# ---
#
# ### **Factores económicos**
# - **Deudas:**
#   - El 62% de los estudiantes con deudas desertan, frente al 28% de quienes no tienen deudas.
#   - La condición de deudor es uno de los predictores más fuertes de deserción.
#
# ---
#
# ### **Desempeño académico en los primeros semestres**
# - **Carga académica y rendimiento:**
#   - Los graduados inscriben y aprueban más materias y obtienen mejores promedios en los primeros semestres.
#   - Los desertores suelen tener menor carga académica, menos materias aprobadas y promedios más bajos.
#   - La identificación temprana de bajo rendimiento puede ayudar a prevenir la deserción.
#
# ---
#
# ### **Edad de ingreso**
# - **Edad al inscribirse:**
#   - Los graduados suelen ingresar a menor edad.
#   - Ingresar a mayor edad se asocia con mayor riesgo de deserción.
#
# ---
#
#
# Las **variables más relevantes** para el modelo de Red Neuronal Artificial (RNA) son:
#
# - **Estado civil:** Situación personal que puede influir en la permanencia escolar.
# - **Género:** Diferencias en patrones de deserción entre hombres y mujeres.
# - **Modalidad de aplicación:** Tipo de proceso de ingreso a la universidad.
# - **Orden de aplicación:** Prioridad con la que el estudiante eligió el programa académico.
# - **Nivel educativo previo:** Máximo grado académico alcanzado antes de ingresar.
# - **Calificaciones previas:** Desempeño académico antes de la universidad.
# - **Calificación de admisión:** Resultado obtenido en el proceso de admisión.
# - **Escolaridad de los padres:** Nivel educativo de la madre y el padre.
# - **Condición de deudor:** Si el estudiante tiene deudas con la institución.
# - **Beca:** Si el estudiante es beneficiario de una beca.
# - **Edad de ingreso:** Edad al momento de inscribirse en la universidad.
# - **Carga académica en los primeros semestres:** Número de materias inscritas y aprobadas.
# - **Rendimiento en los primeros semestres:** Promedio de calificaciones y desempeño académico inicial.
#
#
# Estas variables capturan tanto factores académicos como socioeconómicos y demográficos, pueden permitir al modelo identificar patrones complejos y no lineales asociados a la deserción escolar. El modelo debe desarrollarse al desbalance de clases, a la influencia de las variables económicas y de rendimiento académico temprano.
#
# ---

# %% [markdown]
# # 8. **Modelado de Datos**
#
# El modelado de datos en este proyecto se centra en el desarrollo de una **Red Neuronal Artificial (RNA) multicapa** utilizando el algoritmo de **backpropagation** para predecir la deserción escolar en estudiantes universitarios. El objetivo es identificar, a partir de variables académicas, demográficas y socioeconómicas, los factores que más influyen en la permanencia o abandono de los estudios superiores.
#
# El proceso de modelado se desarrolla en los siguientes pasos:
#
# - **Carga de datos:** Se utiliza un conjunto de datos históricos de estudiantes, que incluye información relevante como estado civil, modalidad de ingreso, calificaciones previas, escolaridad de los padres, condición de deudor, beca, edad de ingreso, carga académica y rendimiento en los primeros semestres, entre otras variables.
#
# - **Selección de datos de entrenamiento, validación y prueba:** Se divide el conjunto de datos en tres subconjuntos: entrenamiento, validación y prueba. Esto permite entrenar el modelo con una parte de los datos, ajustar hiperparámetros y validar su desempeño con otro subconjunto, y finalmente evaluar su capacidad de generalización en un conjunto independiente. El proceso de la evaluación del modelo es objetivo y los resultados obtenidos son representativos del rendimiento real ante nuevos casos.
#
# - **Construcción del modelo:** Se implementa una red neuronal multicapa (MLP) con una o más capas ocultas y funciones de activación no lineales. La capa de salida utiliza activación softmax para clasificación multiclase (Dropout, Graduate, Enrolled). El algoritmo de **backpropagation** se emplea para ajustar los pesos de la red mediante descenso del gradiente, minimizando el error de predicción.
#
# - **Entrenamiento del modelo:** El modelo se entrena utilizando los datos históricos, dividiendo el conjunto en entrenamiento y prueba para validar la capacidad de generalización de la red. Se ajustan los hiperparámetros como el número de neuronas, capas ocultas y tasa de aprendizaje.
#
# - **Validación del modelo:** Se evalúa el rendimiento del modelo mediante métricas como accuracy, precisión, recall, F1-score y matriz de confusión. Se analiza la curva ROC y el AUC para medir la capacidad discriminativa del modelo.
#
# - **Predicción y toma de decisiones:** El modelo entrenado permite predecir la probabilidad de deserción de nuevos estudiantes, identificando aquellos en mayor riesgo y facilitando la implementación de estrategias de retención y acompañamiento académico.
#
# ---

# %% [markdown]
# ## 8.1 **Carga de datos**

# %%
df.head()
# Out:
#    marital_status  application_mode  application_order  course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    daytime_evening_attendance  previous_qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    previous_qualification_grade  nacionality  mothers_qualification  \
# 0                         122.0            1                     19
# 1                         160.0            1                      1
# ...

# %%
# X: todas las columnas excepto 'target', Y: columna 'target'
X = df.drop('target', axis=1).values
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
Y = df['target'].values

# Verifica que X y Y no estén vacíos antes de dividir
print("Shape de X:", X.shape)
print("Shape de Y:", Y.shape)
# Out:
# Shape de X: (4424, 36)
# Shape de Y: (4424,)

# %% [markdown]
# ## 8.2 **Selección de datos de entrenamiento, validación y prueba**

# %%
# División 60% entrenamiento, 20% validación, 20% prueba
x_train, x_temp, y_train, y_temp = train_test_split(
    X_scaled, Y, test_size=0.4, random_state=42, stratify=Y
)
x_val, x_test, y_val, y_test = train_test_split(
    x_temp, y_temp, test_size=0.5, random_state=42, stratify=y_temp
)

# %%
print("Shape de x_train:", x_train.shape)
print("Shape de x_val:", x_val.shape)
print("Shape de x_test:", x_test.shape)

# Convertir etiquetas a códigos numéricos para bincount
y_train_codes = pd.Categorical(y_train).codes
y_val_codes = pd.Categorical(y_val, categories=pd.Categorical(y_train).categories).codes
y_test_codes = pd.Categorical(y_test, categories=pd.Categorical(y_train).categories).codes

print("Distribución de clases en y_train:", np.bincount(y_train_codes))
print("Distribución de clases en y_val:", np.bincount(y_val_codes))
print("Distribución de clases en y_test:", np.bincount(y_test_codes))
# Out:
# Shape de x_train: (2654, 36)
# Shape de x_val: (885, 36)
# Shape de x_test: (885, 36)
# Distribución de clases en y_train: [ 853  476 1325]
# Distribución de clases en y_val: [284 159 442]
# Distribución de clases en y_test: [284 159 442]

# %%
# Visualización simple del train set usando las dos primeras características principales (PCA)
from sklearn.decomposition import PCA

# Reducir a 2 dimensiones para visualizar
pca = PCA(n_components=2)
x_train_2d = pca.fit_transform(x_train)

# Convertir etiquetas a códigos numéricos para colorear
y_train_codes = pd.Categorical(y_train).codes

plt.figure(figsize=(8,6))
scatter = plt.scatter(x_train_2d[:,0], x_train_2d[:,1], c=y_train_codes, cmap='viridis', alpha=0.7, s=20)
plt.xlabel('Componente principal 1')
plt.ylabel('Componente principal 2')
plt.title('Visualización 2D del set de entrenamiento (PCA)')
plt.legend(handles=scatter.legend_elements()[0], labels=pd.Categorical(y_train).categories.tolist(), title="Clase")
plt.show()

# %% [markdown]
# ## 8.3 **Visualización de los datos de entrenamiento, validación y prueba**
#
# La gráfica muestra una **visualización 2D del set de entrenamiento** usando las dos primeras componentes principales (PCA). Cada punto representa un estudiante, coloreado según su clase (`Dropout`, `Enrolled`, `Graduate`).
#
# **Separación parcial de clases:**
# No existe una separación clara entre las clases; los puntos de diferentes clases se mezclan en varias regiones del espacio. Esto indica que, aunque pueden existir ciertos patrones, las clases no son linealmente separables solo con dos componentes principales.
#
# **Solapamiento:**
# Se observa un solapamiento considerable entre los estudiantes que desertan, se gradúan o siguen inscritos. Esto sugiere que los factores que determinan la deserción o graduación son complejos y multidimensionales.
#
# **Distribución de datos:**
# Los datos se distribuyen en varias "bandas" o agrupaciones, lo que puede reflejar la influencia de variables categóricas o la presencia de subgrupos en los datos.
#
#
# El modelo necesita utilizar características (dimensiones) y relaciones no lineales para distinguir las clases.

# %% [markdown]
# ## 8.4 **Construcción del modelo**
#
# En base al análisis de los diferentes resultados del AED, se tomó la decisión de crear un modelo supervisado utilizando una **RNA**  para predecir la deserción escolar.
#
# Se implementa una red neuronal multicapa (MLP) con algoritmo de **backpropagation**, que contiene una o más capas ocultas y funciones de activación no lineales. La capa de salida utiliza una funcion de activación para clasificación multiclase (`Dropout`, `Graduate`, `Enrolled`). El algoritmo de **backpropagation** ajusta los pesos de la red mediante descenso del gradiente, minimizando el error de predicción.
#
# ---

# %% [markdown]
# ## 8.4.1 **Algoritmo Backpropagation**
#
# **Backpropagation (BP)** es un método fundamental de **aprendizaje supervisado** en las redes neuronales artificiales (RNA).
#
# ---
#
# ### História
#
# - **1970** – *Seppo Linnainmaa* introduce por primera vez el concepto de **diferenciación automática (AD)**, aplicado posteriormente en la retropropagación en **perceptrones multicapa**.
#
# - **1974** – *Paul John Werbos* propone en su tesis doctoral _“Beyond Regression: New Tools for Prediction and Analysis in the Behavioral Sciences”_ un método de optimización general para derivar funciones complejas anidadas usando diferenciación automática. Aunque no fue ampliamente adoptado en ese momento.
#
# - **1985** – *David E. Rumelhart*, *Geoffrey E. Hinton* y *Ronald J. Williams* publican el artículo clave _“Learning Representations by Back-Propagating Errors”_, marcando un hito en el uso práctico del algoritmo.
#
# - **1986** – Diversas publicaciones expanden el algoritmo:
#   - *David Parker*, *David Rumelhart* y *Yann LeCun* desarrollan la variante **BPTT (Backpropagation Through Time)**.
#   - *Yann LeCun* publica _“Learning Processes in an Asymmetric Threshold Network. In Disordered Systems and Biological Organization”_.
#   - *David E. Rumelhart* y *James McClelland* presentan _“Parallel Distributed Processing: Explorations in the Microstructure of Cognition”_.
#
# ---
#
# ### ¿Cómo funciona Backpropagation?
#
# **Backpropagation** se basa en el cálculo del **gradiente del error** y la aplicación de la **regla de la cadena** para actualizar los pesos de la red neuronal.
#
# 1. Se calcula la **salida de la red** y se compara con el **resultado deseado**.
# 2. Se determina el **error**.
# 3. El error se **propaga hacia atrás** desde la capa de salida hasta la capa de entrada.
# 4. Los **pesos se ajustan** en función de este error.
# 5. El proceso se **repite** hasta que el error sea mínimo o aceptable.
#
# Este procedimiento permite a la red **aprender de manera iterativa y supervisada**.
#
# ---
# > El aprendizaje en redes neuronales mediante **backpropagation** consiste en la aplicación repetida de la **regla de la cadena** para calcular la **influencia de cada peso** sobre una función de error `f(e)`:
#
# $$
# \frac{\partial e}{\partial w_{ij}} = \frac{\partial e}{\partial s_i} \frac{\partial s_i}{\partial net_i} \frac{\partial net_i}{\partial w_{ij}}
# $$
#
# Donde:
# - $w_{ij}$ es el peso de la neurona $j$ a la neurona $i$.
# - $s_i$ es el resultado (salida) de la neurona $i$.
# - $net_i$ es la suma ponderada de las entradas de la neurona $i$.
#
# Una vez que se conoce la derivada parcial para cada peso, el objetivo es reducir la función de error $e$. Esto se logra realizando un **descenso de gradiente** simple. En la página [gradiente descendente](#) se puede ver un ejemplo.
#
# ---

# %% [markdown]
# ### Ejemplo
#
# #### Algoritmo de Retropropagación
#
# En cada ciclo de entrenamiento del algoritmo de retropropagación:
#
# 1. La **salida actual** se compara con la **salida deseada**
# 2. Se calcula el error para las unidades de salida
# 3. Los pesos en la capa de salida se ajustan para reducir el error
# 4. Esto proporciona un error estimado para las neuronas ocultas
# 5. El proceso se repite hacia atrás (retropropagación)
#
# #### Simplificaciones del ejemplo:
#
# - Se consideran solo **2 neuronas** (sin capas ocultas complejas)
# - **No se actualizan los sesgos** (biases) para simplificar
# - Implementado en **hoja de cálculo** (más legible que código tradicional)
#
# #### Resultados preliminares:
#
# Con solo **2 ciclos** de entrenamiento ya se observa mejoría. El gráfico adjunto complementa esta evolución visualmente.
#
#
# <p align="center">
#   <img src="../img/Backpropagation.png" width="600" height="400">
# </p>

# %% [markdown]
# ## 8.4.2 **Arquitectura de la RNA**
#
# La RNA se ha diseñado específicamente para abordar el problema de predicción de deserción estudiantil utilizando el DataFrame `df`, que contiene variables académicas, demográficas y socioeconómicas relevantes.
#
# La arquitectura propuesta es la siguiente:
#
# - **Capa de entrada**: 18 neuronas ($x \in \mathbb{R}^{18}$)
# - **Capas ocultas**: 3 capas con activación Tanh
#   - Capa 1: 32 neuronas ($W^{(1)} \in \mathbb{R}^{32×18}$, $b^{(1)} \in \mathbb{R}^{32}$)
#   - Capa 2: 24 neuronas ($W^{(2)} \in \mathbb{R}^{24×32}$, $b^{(2)} \in \mathbb{R}^{24}$)
#   - Capa 3: 16 neuronas ($W^{(3)} \in \mathbb{R}^{16×24}$, $b^{(3)} \in \mathbb{R}^{16}$)
# - **Capa de salida**: Softmax ($W^{(out)} \in \mathbb{R}^{C×16}$, $b^{(out)} \in \mathbb{R}^{C}$)
#   (donde $C$ = número de clases)
#
# Esta arquitectura permite capturar patrones los datos y realizar una clasificación multiclase para predecir el riesgo de deserción, permanencia o graduación de los estudiantes.
#
# ## Parametros
# - **Optimizador**: Descenso de Gradiente Estocástico (SGD) con tasa de aprendizaje $\eta$
# - **Derivada de Tanh**: $\frac{\partial h^{(k)}}{\partial a^{(k)}} = 1 - \tanh^2(a^{(k)})$
# - **Eficiencia**: El cálculo se vectoriza en implementaciones reales.

# %% [markdown]
# <p align="center">
#   <img src="../img/Arquitectura_rna.png" width="600" height="400">
# </p>

# %%
#Neuronas de entrada
n_input = x_train.shape[1]
#Neuronas en capas ocultas
n_hidden1 = 32  # Capa oculta 1
n_hidden2 = 24  # Capa oculta 2
n_hidden3 = 16  # Capa oculta 3
#Número de capas ocultas
K = 3
#Neuronas de salida
n_output = 3

# %% [markdown]
# ## 8.4.3 **Entrenamiento del Modelo**
#
# - **Entrenamiento y ajuste de hiperparámetros:** El modelo se entrena con los datos y se ajustan parámetros como el número de neuronas, capas ocultas y tasa de aprendizaje, utilizando el conjunto de validación para evitar el sobreajuste.
#
# La <b>Inicialización</b> de los parámetros se hará de forma aleatoria y con una varianza $\sqrt{n_k}$
#
# ---

# %%
#Semilla
# Inicialización de pesos y sesgos según la arquitectura
np.random.seed(0)
# Pesos y sesgos capa 1
w1 = np.random.randn(n_hidden1, n_input) / np.sqrt(n_input)
b1 = np.ones(n_hidden1)
# Pesos y sesgos capa 2
w2 = np.random.randn(n_hidden2, n_hidden1) / np.sqrt(n_hidden1)
b2 = np.ones(n_hidden2)
# Pesos y sesgos capa 3
w3 = np.random.randn(n_hidden3, n_hidden2) / np.sqrt(n_hidden2)
b3 = np.ones(n_hidden3)
# Pesos y sesgos capa de salida
w_out = np.random.randn(n_output, n_hidden3) / np.sqrt(n_hidden3)
b_out = np.ones(n_output)


print(w1.shape, w2.shape, w3.shape, w_out.shape)
print(b1.shape, b2.shape, b3.shape, b_out.shape)
# Out:
# (32, 36) (24, 32) (16, 24) (3, 16)
# (32,) (24,) (16,) (3,)

# %% [markdown]
# Definimos los hiperparámetros del aprendizaje:
#
# * Rango de aprendizaje $\eta = 0.0001$
# * Número de épocas $T=150$

# %%
#Rango de aprendizaje
lr = 0.0001
#Número de épocas
epochs = 150

# %% [markdown]
# ### 8.4.3.1 **Entrenamiento con backprop y SGD**
#
# El entrenamiento consta de dos pasos:
#
# * <b>Forward</b>: Se calcula el valor de la salidad pasando por las capas ocultas:
#     * Preactivación: $a^{(k)} =  W^{(k)}h^{(k-1)}+b^{(k)}$, con $h^{(0)} = x$
#     * Activación: $h^{(k)} = \tanh(a^{(1)})$
#     * Preactivación en salida: $a^{(out)} = W^{(out)}h^{(3)}+b^{(out)}$
#     * Activación en salida: $f = Softmax\big(a^{(out)}\big)$
# * <b>Bacward</b>: El backward utiliza el algoritmo de backpropagation y el SGD para actualizar. Se calculan las variables de backprop, en base a la función de riesgo $$R(\theta) = -\sum_x \sum_y y \ln f(x)$$ Las variables son:
#     * $d_{out}(j) = \frac{\partial R(\theta)}{\partial f_j} \frac{\partial f_j}{\partial a^{(out)}} = f_j - \delta_{y,j}$
#     * $d_{k}(j) = \frac{\partial h^{(k)}}{\partial a^{(k)}} \sum_q W^{(k+1)}_{j,q} d_{k+1}(q)$
#
#   En este caso, $\frac{\partial h^{(k)}}{\partial a^{(k)}} = 1-\tanh^2(a^{(k)})$. Y tenemos que: $$\delta_{y,j} = \begin{cases} 1 & \text{si } y=j \\
#   0 & \text{en otro caso} \end{cases}$$

# %%
# Asegúrate de que x_train es float
x_train_float = x_train.astype(float)

loss = []
train_data = list(zip(x_train_float, y_train_codes))

for t in tqdm(range(epochs)):
    np.random.shuffle(train_data)
    risk_epoch = 0
    for x, y in train_data:
        # FORWARD
        # Capa 1
        a1 = np.dot(w1, x) + b1
        h1 = np.tanh(a1)
        # Capa 2
        a2 = np.dot(w2, h1) + b2
        h2 = np.tanh(a2)
        # Capa 3
        a3 = np.dot(w3, h2) + b3
        h3 = np.tanh(a3)
        # Capa de salida
        a_out = np.dot(w_out, h3) + b_out
        tmp = np.exp(a_out - np.max(a_out))  # para estabilidad numérica
        f = tmp / tmp.sum()

        # Riesgo
        risk_epoch -= np.log(f[int(y)])

        # BACKWARD
        # Salida
        d_out = f.copy()
        d_out[int(y)] -= 1

        # Gradientes capa de salida
        w_out -= lr * np.outer(d_out, h3)
        b_out -= lr * d_out

        # Capa 3
        d3 = (1 - h3 ** 2) * np.dot(w_out.T, d_out)
        w3 -= lr * np.outer(d3, h2)
        b3 -= lr * d3

        # Capa 2
        d2 = (1 - h2 ** 2) * np.dot(w3.T, d3)
        w2 -= lr * np.outer(d2, h1)
        b2 -= lr * d2

        # Capa 1
        d1 = (1 - h1 ** 2) * np.dot(w2.T, d2)
        w1 -= lr * np.outer(d1, x)
        b1 -= lr * d1

    loss.append(risk_epoch)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 150/150 [00:13<00:00, 11.17it/s]

# %% [markdown]
# #### Visualización del riesgo

# %%
plt.plot(loss)
plt.title('Pérdida del riesgo a través de las épocas')
plt.xlabel('Epoch')
plt.ylabel('Riesgo')
plt.show()

# %% [markdown]
# La gráfica de **"Pérdida del riesgo a través de las épocas"** muestra cómo evoluciona la función de pérdida (riesgo) durante el entrenamiento de la red neuronal. En un entrenamiento efectivo, se espera que la pérdida disminuya progresivamente a medida que el modelo aprende a predecir mejor.
#
# ### ¿Qué indica la gráfica si hay perdida?
#
# La gráfica muestra cómo evoluciona la función de pérdida (riesgo) durante el entrenamiento de la red neuronal. Se observa que:
#
# - **La pérdida disminuye rápidamente al inicio**, lo que indica que el modelo está aprendiendo y ajustando sus parámetros correctamente en las primeras épocas.
#
# - **Después de aproximadamente la época 30-40, la pérdida se estabiliza** y presenta pequeñas oscilaciones, pero ya no disminuye de forma significativa.
#
# - **No hay incrementos abruptos ni explosión del riesgo**, lo que sugiere que el entrenamiento es estable.
#
# El modelo logra aprender de los datos y reduce el riesgo de manera efectiva al inicio del entrenamiento. Sin embargo, después de cierto punto, el aprendizaje se ralentiza y la función de pérdida se estabiliza, lo cual es un comportamiento esperado. Para mejorar aún más, podrías probar con más épocas, ajustar la tasa de aprendizaje o modificar la arquitectura, pero el comportamiento general indica un entrenamiento adecuado.
#
# ### ¿Qué indica la gráfica si NO hay perdida?
#
# - **Estabilidad sin tendencia descendente:**
#   La curva de pérdida se mantiene relativamente estable y no muestra una tendencia clara a la baja, sino que oscila alrededor de un valor similar en todas las épocas.
#
# - **Posibles causas:**
#   Esto puede indicar que el modelo **no está aprendiendo de manera efectiva**. Las causas más comunes pueden ser:
#   - Tasa de aprendizaje inadecuada.
#   - Arquitectura demasiado compleja (por ejemplo, un número excesivo de capas ocultas, como K=100).
#   - Pesos mal inicializados.
#   - Datos sin escalar o normalizar correctamente.
#   - Problemas de desvanecimiento/explosión del gradiente.
#
# ### ¿Qué se espera en un entrenamiento exitoso?
#
# - La pérdida debería **disminuir de forma notoria al principio** y luego estabilizarse en un valor bajo.
#
# ### Recomendaciones para mejorar el entrenamiento
#
# - **Reduce la complejidad de la red:** Prueba con menos capas ocultas (por ejemplo, K=2 a 5).
# - **Ajusta la tasa de aprendizaje:** Prueba valores más bajos o más altos.
# - **Verifica el preprocesamiento:** Asegúrate de que los datos estén correctamente escalados o normalizados.
# - **Prueba con menos épocas:** Observa si la tendencia cambia en las primeras iteraciones.
#
# Si el modelo **no está mejorando su desempeño** durante el entrenamiento. Es recomendable ajustar los hiperparámetros y la arquitectura para lograr una reducción efectiva de la pérdida y un aprendizaje real del modelo.

# %% [markdown]
# ## 8.4.4 **Validación del modelo**
#
# Para la evaluación utilizamos una función de predicción, y evaluamos usando un reporte de clasificación:

# %%
def predict(x):
    # Forward pass for a single sample x
    a1 = np.dot(w1, x) + b1
    h1 = np.tanh(a1)
    a2 = np.dot(w2, h1) + b2
    h2 = np.tanh(a2)
    a3 = np.dot(w3, h2) + b3
    h3 = np.tanh(a3)
    a_out = np.dot(w_out, h3) + b_out
    tmp = np.exp(a_out - np.max(a_out))  # numerical stability
    f = tmp / tmp.sum()
    return np.argmax(f)

def evaluar_desercion(x_data, y_data, categorias, nombre_set="Validación"):
    x_data_float = x_data.astype(float)
    y_pred_codes = [predict(x) for x in x_data_float]
    y_pred_labels = [categorias[code] for code in y_pred_codes]

    print(f"\n--- Resultados en el set de {nombre_set} ---")
    print(classification_report(y_data, y_pred_labels, target_names=categorias))

    # Visualización de predicciones vs reales
    df_eval = pd.DataFrame(x_data, columns=df.drop('target', axis=1).columns)
    df_eval['Real'] = y_data
    df_eval['Predicha'] = y_pred_labels
    df_eval['Acierto'] = df_eval['Real'] == df_eval['Predicha']

    print("\nPrimeras filas con predicción y clase real:")
    display(df_eval.head())

    print("\nEjemplos de errores de predicción:")
    display(df_eval[df_eval['Acierto'] == False].head())

    desercion_real = (y_data == 'Dropout').sum()
    desercion_pred = (np.array(y_pred_labels) == 'Dropout').sum()
    print(f"Total de casos reales de deserción: {desercion_real}")
    print(f"Total de casos predichos como deserción: {desercion_pred}")

categorias = pd.Categorical(y_train).categories
evaluar_desercion(x_val, y_val, categorias, nombre_set="Validación")
evaluar_desercion(x_test, y_test, categorias, nombre_set="Prueba")
# Out:
# --- Resultados en el set de Validación ---
#               precision    recall  f1-score   support
#
#      Dropout       0.84      0.74      0.78       284
#     Enrolled       0.52      0.43      0.47       159
#     Graduate       0.80      0.91      0.85       442
#
#     accuracy                           0.77       885
#    macro avg       0.72      0.69      0.70       885
# weighted avg       0.76      0.77      0.76       885
#
#
# Primeras filas con predicción y clase real:
#    marital_status  application_mode  application_order    course  \
# 0       -0.294829          1.448913          -0.554068  0.070932
# 1       -0.294829         -1.010660           0.968414  0.311805
# 2       -0.294829         -1.010660          -0.554068  0.311805
# 3       -0.294829         -1.010660           0.968414  0.140722
# 4       -0.294829         -1.010660          -0.554068  0.444115
#
#    daytime_evening_attendance  previous_qualification  \
# ...

# %%
"""def predict(x):
    a1 = np.dot(w1, x) + b1
    h1 = np.tanh(a1)
    a2 = np.dot(w2, h1) + b2
    h2 = np.tanh(a2)
    a3 = np.dot(w3, h2) + b3
    h3 = np.tanh(a3)
    a_out = np.dot(w_out, h3) + b_out
    tmp = np.exp(a_out - np.max(a_out))
    f = tmp / tmp.sum()
    return np.argmax(f)

def evaluar_desercion(x_data, y_data, categorias, nombre_set="Validación"):
    x_data_float = x_data.astype(float)
    y_pred_codes = [predict(x) for x in x_data_float]
    y_pred_labels = [categorias[code] for code in y_pred_codes]
    print(f"\n--- Resultados en el set de {nombre_set} ---")
    print(classification_report(y_data, y_pred_labels, target_names=categorias))
    dropout_idx = categorias.get_loc('Dropout') if hasattr(categorias, 'get_loc') else categorias.index('Dropout')
    desercion_real = (y_data == 'Dropout').sum()
    desercion_pred = (np.array(y_pred_labels) == 'Dropout').sum()
    print(f"Total de casos reales de deserción: {desercion_real}")
    print(f"Total de casos predichos como deserción: {desercion_pred}")

categorias = pd.Categorical(y_train).categories
evaluar_desercion(x_val, y_val, categorias, nombre_set="Validación")
evaluar_desercion(x_test, y_test, categorias, nombre_set="Prueba")
"""
# Out:
# 'def predict(x):\n    a1 = np.dot(w1, x) + b1\n    h1 = np.tanh(a1)\n    a2 = np.dot(w2, h1) + b2\n    h2 = np.tanh(a2)\n    a3 = np.dot(w3, h2) + b3\n    h3 = np.tanh(a3)\n    a_out = np.dot(w_out, h3) + b_out\n    tmp = np.exp(a_out - np.max(a_out))\n    f = tmp / tmp.sum()\n    return np.argmax(f)\n\ndef evaluar_desercion(x_data, y_data, categorias, nombre_set="Validación"):\n    x_data_float = x_data.astype(float)\n    y_pred_codes = [predict(x) for x in x_data_float]\n    y_pred_labels = [categorias[code] for code in y_pred_codes]\n    print(f"\n--- Resultados en el set de {nombre_set} ---")\n    print(classification_report(y_data, y_pred_labels, target_names=categorias))\n    dropout_idx = categorias.get_loc(\'Dropout\') if hasattr(categorias, \'get_loc\') else categorias.index(\'Dropout\')\n    desercion_real = (y_data == \'Dropout\').sum()\n    desercion_pred = (np.array(y_pred_labels) == \'Dropout\').sum()\n    print(f"Total de casos reales de deserción: {desercion_real}")\n
# ...

# %%
# Guardar el modelo de red neuronal entrenado usando pickle
import pickle

# Agrupa los pesos y sesgos en un diccionario
modelo_rna = {
    'w1': w1,
    'b1': b1,
    'w2': w2,
    'b2': b2,
    'w3': w3,
    'b3': b3,
    'w_out': w_out,
    'b_out': b_out,
    'categorias': categorias
}

# Guardar el modelo en un archivo
with open('modelo_rna.pkl', 'wb') as f:
    pickle.dump(modelo_rna, f)

print("Modelo de red neuronal guardado como 'modelo_rna.pkl'")
# Out:
# Modelo de red neuronal guardado como 'modelo_rna.pkl'

# %% [markdown]
# # 9. **Resultados de validación y prueba del modelo de red neuronal**.
#
# ## _"Mejores Resultados de Entrenamiento durante las Pruebas"_**
# ---
#
# ### **Desempeño general (accuracy)**
# - **Exactitud (accuracy):**
#   - **Validación:** 73%
#   - **Prueba:** 73%
#   - El modelo clasifica correctamente la situación final de aproximadamente 3 de cada 4 estudiantes.
#
# ---
#
# ### **Deserción (Dropout)**
# - **Recall (sensibilidad):**
#   - **Validación:** 0.76
#   - **Prueba:** 0.77
#   - El modelo identifica correctamente entre el 76% y 77% de los casos reales de deserción.
# - **Precisión:**
#   - **Validación:** 0.70
#   - **Prueba:** 0.70
#   - De todos los casos predichos como deserción, el 70% realmente desertaron.
# - **Total de casos reales vs. predichos:**
#   - El modelo predice un número de deserciones similar al real (309/284 en validación, 312/284 en prueba), mostrando un leve sobreajuste hacia la clase de deserción.
#
# ---
#
# ### **Graduados (Graduate)**
# - **Recall:**
#   - **Validación:** 0.97
#   - **Prueba:** 0.96
#   - El modelo identifica correctamente casi todos los graduados.
# - **Precisión:**
#   - **Validación:** 0.75
#   - **Prueba:** 0.75
#   - De todos los casos predichos como graduados, el 75% realmente lo son.
#
# ---
#
# ### **Inscritos (Enrolled)**
# - **Recall:**
#   - **Validación:** 0.02
#   - **Prueba:** 0.01
#   - El modelo casi nunca identifica correctamente a los estudiantes que siguen inscritos.
# - **Precisión:**
#   - **Validación:** 1.00
#   - **Prueba:** 0.33
#   - Cuando predice "enrolled", suele acertar, pero lo hace muy pocas veces (muy baja cobertura).
#
# ---
#
# ### **Macro y weighted average**
# - **Macro avg:**
#   - Promedia el desempeño de todas las clases por igual. El recall y f1-score son bajos (~0.53), indicando que el modelo no es equilibrado entre clases.
# - **Weighted avg:**
#   - Promedia ponderando por la cantidad de muestras de cada clase. Mejora por el buen desempeño en "graduate" y "dropout", pero sigue penalizado por la mala predicción de "enrolled".
#
# ---

# %% [markdown]
# # 10. **Conclusión**
#
# El presente reporte presenta la aplicación de un modelo de RNA para resolver un problema de clasificación. A través de un proceso metodológico, que abarcó desde el preprocesamiento y la limpieza de datos hasta la construcción, entrenamiento y evaluación del modelo, se cumple con el objetivo de emplear herramientas de inteligencia artificial para la identificación de patrones y la realización de predicciones con un alto grado de precisión. Esto valida que las RNAs tienen un porcentaje de éxito alto para estas tareas y el avance en técnicas de machine learning actuales.
#
# Se inicio con un tratamiento de los datos (Data Clean), que incluyó la estandarización de valores para asegurar que todas las variables contribuyeran al aprendizaje del modelo, evitando sesgos por diferencias de escala. A continuación, el AED permitió una comprensión profunda de la estructura de los datos, las distribuciones de las variables y sus interrelaciones. Las visualizaciones en esta fase fueron importantes para la toma de decisiones informadas, como la selección de las características más relevantes (feature selection) y el diseño de una arquitectura RNA inicial para el problema.
#
# La implementación de la RNA demostró la capacidad para modelar y aprender de relaciones complejas y no lineales. El modelo fue entrenado para clasificar datos basándose en múltiples variables de entrada, utilizando el algoritmo de backpropagation como motor de aprendizaje. Este mecanismo ajustó iterativamente los pesos sinápticos de la red para minimizar progresivamente la función de pérdida, logrando una solución óptima. El resultado es que la RNA fue capaz de generalizar el conocimiento adquirido a partir de los datos de entrenamiento, permitiendo clasificar nuevas instancias con un alto grado de precisión.
#
# Finalmente, se destaca la implementación en Python, con el uso de bibliotecas como NumPy para operaciones numéricas, Pandas para la manipulación de datos, y Matplotlib/Seaborn para la visualización, junto con Scikit-learn para la construcción y evaluación del modelo,. Este conjunto de herramientas proporciona una flexibilidad y acceso a técnicas que permiten que el desarrollo se realice  en días,  situación que en el pasado habrían requerido meses de esfuerzo en programación.
#
#
#
# ---

# %% [markdown]
# # 11. **Bibliografía**
#
# ---
#
# - **Alejo, R., Monroy, J., Ambriz, J. C., & Pacheco-Sánchez, J. H.** (2017).
#     *An improved dynamic sampling back-propagation algorithm based on mean square error to face the multiclass imbalance problem*.
#     Neural Computing and Applications, 28(10), 2843–2857.
#
# - **Andreu, M. E., Pareja, R. M., & Gelabert, A. S.** (2020).
#     *Aspiraciones ocupacionales y expectativas y elecciones educativas de los jóvenes en un contexto de crisis*.
#     Revista Española de Sociología, 29(3), 27–46.
#     [Ver artículo](https://recyt.fecyt.es/index.php/res/article/view/85849)
#
# - **Benítez, J. M., Castro, J. L., & Requena, I.** (1997).
#     *Are artificial neural networks black boxes?*
#     IEEE Transactions on Neural Networks, 8(5), 1156–1164.
#
# - **Caicedo Bravo, E., & López Sotelo, J.** (2009).
#     *Una aproximación práctica a las redes neuronales artificiales*.
#     Programa Editorial Universidad del Valle.
#
# - **Duda, R., Hart, P., & Stork, D.** (2001).
#     *Pattern classification and scene analysis*.
#     Wiley.
#
# - **Eckert, K. B., & Suénaga, R.** (2015).
#     *Análisis de deserción permanencia de estudiantes universitarios utilizando técnica de clasificación en minería de datos*.
#     Formación Universitaria, 8(5), 3–12.
#
# - **Estrada, M.** (2018).
#     *Abandono escolar en la educación media superior de México, políticas, actores y análisis de casos* (1ra ed.).
#     [Descargar PDF](http://www.dcsh.ugto.mx/editorial/images/abandono%20escolar%20EBOOK%20(1).pdf)
#
# - **Fernández, A., García, S., & Herrera, F.** (2018).
#     *SMOTE for learning from imbalanced data: Progress and challenges, marking the 15-year anniversary*.
#     Journal of Artificial Intelligence Research, 61(1), 863–905.
#
# - **Flóres López, R., & Fernandez, J.** (2008).
#     *Las redes neuronales artificiales*.
#     Gesbiblio S.L.
#
# - **Graupe, D.** (2013).
#     *Principios de redes neuronales artificiales* (Vol. 7). World Scientific.
#     [Ver libro](https://books.google.es/books?id=Zz27CgAAQBAJ)
#
# - **Heredia, D., Amaya, Y., & Barrientos, E.** (2015).
#     *Student dropout predictive model using data mining techniques*.
#     IEEE Latin America Transactions, 9(13), 3127–3134.
#
# - **Incio, F., Capuñay Sanchez, D., Estela Urbina, R., Delgado Soto, J., & Vergara Medrano, S.** (2021).
#     *Diseño e implementación de una red neuronal artificial para predecir el rendimiento académico en estudiantes de Ingeniería Civil de la UNIFSLB*.
#     Veritas et Scientia, 11.
#
# - **Zambrano Matamala, C., Rojas Díaz, D., Carvajal Cuello, K., & Acuña Leiva, G.** (2011).
#     *Análisis de rendimiento académico estudiantil usando data warehouse y redes neuronales*.
#     Ingeniare. Revista Chilena de Ingeniería, 14.
#
# ---
